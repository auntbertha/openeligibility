# %%
import requests
from pyquery import PyQuery as pq
from slugify import slugify

# %% [markdown]
# ### Load and parse data from https://company.auntbertha.com/the-open-eligibility-project

# %%
URL = 'https://company.auntbertha.com/the-open-eligibility-project/'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:92.0) Gecko/20100101 Firefox/92.0'
}

# %%
page = pq(requests.get(URL, headers=HEADERS).text)

# %%
container = pq(page('.entry-content .container'))

# %%
names = dict()

def get_item(*parts):
    if len(parts) == 1:
        name = parts[0]
        prefix = ''
    else:
        name = parts[1]
        prefix = parts[0] + ':'
    slug = slugify(name, separator='_')
    ret = dict(name=name, slug=prefix + slug)
    names.setdefault(name, []).append(ret)
    return ret

# %%
def parse_ul(section, element, level):
    items = section.setdefault('items', [])
    for el in element.children():
        if el.tag == 'li':
            header = el.text.strip().replace("\u2019", "'")
            item = get_item(section['slug'], header)
            print('>>'*level, item['slug'])
            items.append(item)
            ul = pq(el)('ul')
            if ul:
                item['items'] = []
                parse_ul(item, pq(ul), level+1)

# %%
sections = []
section = None
subsection = None
stack = []
for child in container.children():
    if child.tag == 'h3':
        if len(sections) == 2:
            break
        header = pq(child).text().strip()
        if header:
            section = get_item(header)
            sections.append(section)
            subsection = None
            print('===', section['slug'])
    elif child.tag == 'p':
        header = pq(child)('strong').text().strip()
        description = pq(child).text()
        if section is not None:
            if header:
                subsection = get_item(section['slug'], slugify(header))
                section.setdefault('items', []).append(subsection)
#                 print('>>', header)
                print('>>', subsection['slug'])
            elif description:
                current = subsection or section 
                current['description'] = description
                print('ddd:', description)

    elif child.tag == 'ul':
        current = subsection or section
        if current is not None:
            parse_ul(current, pq(child), 2)
# Out:
# === human_services
# >> human_services:food
# ddd: Services for meals, food pantries, help paying for food, food delivery, food benefits, and nutrition support.
# >>>> human_services:food:community_gardens
# >>>> human_services:food:emergency_food
# >>>> human_services:food:food_delivery
# >>>> human_services:food:food_pantry
# >>>> human_services:food:meals
# >>>> human_services:food:help_pay_for_food
# >>>>>> human_services:food:help_pay_for_food:government_food_benefits
# >>>> human_services:food:nutrition_education
# >> human_services:housing
# ddd: Services for emergency, short- term and long- term housing, housing advice, help finding housing, and paying for housing.
# >>>> human_services:housing:temporary_shelter
# >>>>>> human_services:housing:temporary_shelter:weather_relief
# >>>> human_services:housing:help_find_housing
# >>>> human_services:housing:help_pay_for_housing
# >>>>>> human_services:housing:help_pay_for_housing:help_pay_for_utilities
# >>>>>> human_services:housing:help_pay_for_housing:help_pay_for_internet_or_phone
# >>>>>> human_services:housing:help_pay_for_housing:home_renters_insurance
# >>>>>> human_services:housing:help_pay_for_housing:housing_vouchers
# >>>> human_services:housing:maintenance_repairs
# >>>>>> human_services:housing:maintenance_repairs:efficiency_upgrades
# >>>>>> human_services:housing:maintenance_repairs:health_safety
# >>>>>> human_services:housing:maintenance_repairs:pest_control
# >>>> human_services:housing:housing_advice
# >>>>>> human_services:housing:housing_advice:foreclosure_counseling
# >>>>>> human_services:housing:housing_advice:homebuyer_education
# >>>> human_services:housing:residential_housing
# >>>>>> human_services:housing:residential_housing:long_term_housing
# >>>>>>>> human_services:housing:residential_housing:long_term_housing:assisted_living
# >>>>>>>> human_services:housing:residential_housing:long_term_housing:independent_living
# >>>>>>>> human_services:housing:residential_housing:long_term_housing:nursing_home
# >>>>>>>> human_services:housing:residential_housing:long_term_housing:public_housing
# >>>>>> human_services:housing:residential_housing:safe_housing
# >>>>>> human_services:housing:residential_housing:short_term_housing
# >>>>>>>> human_services:housing:residential_housing:short_term_housing:nursing_home
# >>>>>>>> human_services:housing:residential_housing:short_term_housing:sober_living
# >>>>>> human_services:housing:residential_housing:assisted_living
# >>>>>> human_services:housing:residential_housing:independent_living
# >>>>>> human_services:housing:residential_housing:nursing_home
# >>>>>> human_services:housing:residential_housing:public_housing
# >>>>>> human_services:housing:residential_housing:nursing_home
# >>>>>> human_services:housing:residential_housing:sober_living
# >> human_services:goods
# ddd: Services for clothing, furniture, baby supplies, toys and gifts, and other physical goods.
# >>>> human_services:goods:baby_supplies
# >>>>>> human_services:goods:baby_supplies:baby_clothes
# >>>>>> human_services:goods:baby_supplies:diapers_formula
# >>>> human_services:goods:clothing
# >>>>>> human_services:goods:clothing:baby_clothes
# >>>>>> human_services:goods:clothing:clothes_for_school
# >>>>>> human_services:goods:clothing:clothes_for_work
# >>>>>> human_services:goods:clothing:clothing_vouchers
# >>>> human_services:goods:home_goods
# >>>>>> human_services:goods:home_goods:blankets_fans
# >>>>>> human_services:goods:home_goods:books
# >>>>>> human_services:goods:home_goods:furniture
# >>>>>> human_services:goods:home_goods:home_fuels
# >>>>>> human_services:goods:home_goods:efficient_appliances
# >>>>>> human_services:goods:home_goods:personal_care_items
# >>>>>> human_services:goods:home_goods:supplies_for_school
# >>>>>> human_services:goods:home_goods:supplies_for_work
# >>>> human_services:goods:medical_supplies
# >>>>>> human_services:goods:medical_supplies:assistive_technology
# >>>>>> human_services:goods:medical_supplies:prosthesis
# >>>> human_services:goods:personal_safety
# >>>> human_services:goods:toys_gifts
# >> human_services:transit
# ddd: Services for bus passes, transportation to school, healthcare, appointments, and more.
# >>>> human_services:transit:help_pay_for_transit
# >>>>>> human_services:transit:help_pay_for_transit:bus_passes
# >>>>>> human_services:transit:help_pay_for_transit:help_pay_for_car
# >>>>>> human_services:transit:help_pay_for_transit:help_pay_for_gas
# >>>> human_services:transit:transportation
# >>>>>> human_services:transit:transportation:transportation_for_healthcare
# >>>>>> human_services:transit:transportation:transportation_for_school
# >> human_services:health
# ddd: Services for medical care, dental care, health education, addiction and recovery, help finding services, and help paying for healthcare.
# >>>> human_services:health:addiction_recovery
# >>>>>> human_services:health:addiction_recovery:12_step
# >>>>>> human_services:health:addiction_recovery:detox
# >>>>>> human_services:health:addiction_recovery:drug_testing
# >>>>>> human_services:health:addiction_recovery:medications_for_addiction
# >>>>>> human_services:health:addiction_recovery:outpatient_treatment
# >>>>>> human_services:health:addiction_recovery:peer_recovery_coaching
# >>>>>> human_services:health:addiction_recovery:residential_treatment
# >>>>>> human_services:health:addiction_recovery:sober_living
# >>>>>> human_services:health:addiction_recovery:substance_abuse_counseling
# >>>> human_services:health:dental_care
# >>>> human_services:health:end_of_life_care
# >>>>>> human_services:health:end_of_life_care:bereavement
# >>>>>> human_services:health:end_of_life_care:burial_funeral_help
# >>>>>> human_services:health:end_of_life_care:hospice
# >>>> human_services:health:health_education
# >>>>>> human_services:health:health_education:daily_life_skills
# >>>>>> human_services:health:health_education:disease_management
# >>>>>> human_services:health:health_education:family_planning
# >>>>>> human_services:health:health_education:nutrition_education
# >>>>>> human_services:health:health_education:parenting_education
# >>>>>> human_services:health:health_education:safety_education
# >>>>>> human_services:health:health_education:sex_education
# >>>>>> human_services:health:health_education:understand_disability
# >>>>>> human_services:health:health_education:understand_mental_health
# >>>> human_services:health:help_pay_for_healthcare
# >>>>>> human_services:health:help_pay_for_healthcare:disability_benefits
# >>>>>> human_services:health:help_pay_for_healthcare:discounted_healthcare
# >>>>>> human_services:health:help_pay_for_healthcare:health_insurance
# >>>>>> human_services:health:help_pay_for_healthcare:prescription_assistance
# >>>>>> human_services:health:help_pay_for_healthcare:transportation_for_healthcare
# >>>> human_services:health:medical_care
# >>>>>> human_services:health:medical_care:alternative_medicine
# >>>>>> human_services:health:medical_care:checkup_test
# >>>>>>>> human_services:health:medical_care:checkup_test:disability_screening
# >>>>>>>> human_services:health:medical_care:checkup_test:disease_screening
# >>>>>>>> human_services:health:medical_care:checkup_test:hearing_tests
# >>>>>>>> human_services:health:medical_care:checkup_test:pregnancy_tests
# >>>>>> human_services:health:medical_care:exercise_fitness
# >>>>>> human_services:health:medical_care:help_find_healthcare
# >>>>>> human_services:health:medical_care:medical_supplies
# >>>>>>>> human_services:health:medical_care:medical_supplies:assistive_technology
# >>>>>>>> human_services:health:medical_care:medical_supplies:prosthesis
# >>>>>> human_services:health:medical_care:prevent_treat
# >>>>>>>> human_services:health:medical_care:prevent_treat:counseling
# >>>>>>>> human_services:health:medical_care:prevent_treat:disease_management
# >>>>>>>> human_services:health:medical_care:prevent_treat:early_childhood_intervention
# >>>>>>>> human_services:health:medical_care:prevent_treat:hiv_treatment
# >>>>>>>> human_services:health:medical_care:prevent_treat:hospital_treatment
# >>>>>>>> human_services:health:medical_care:prevent_treat:in_home_support
# >>>>>>>> human_services:health:medical_care:prevent_treat:medication_management
# >>>>>>>> human_services:health:medical_care:prevent_treat:nursing_home
# >>>>>>>> human_services:health:medical_care:prevent_treat:occupational_therapy
# >>>>>>>> human_services:health:medical_care:prevent_treat:outpatient_treatment
# >>>>>>>> human_services:health:medical_care:prevent_treat:pain_management
# >>>>>>>> human_services:health:medical_care:prevent_treat:physical_therapy
# >>>>>>>> human_services:health:medical_care:prevent_treat:residential_treatment
# >>>>>>>> human_services:health:medical_care:prevent_treat:specialized_therapy
# >>>>>>>> human_services:health:medical_care:prevent_treat:speech_therapy
# >>>>>>>> human_services:health:medical_care:prevent_treat:vaccinations
# >>>>>> human_services:health:medical_care:personal_hygiene
# >>>>>> human_services:health:medical_care:primary_care
# >>>>>> human_services:health:medical_care:skilled_nursing
# >>>>>> human_services:health:medical_care:support_service_animals
# >>>>>> human_services:health:medical_care:disability_screening
# >>>>>> human_services:health:medical_care:disease_screening
# >>>>>> human_services:health:medical_care:hearing_tests
# >>>>>> human_services:health:medical_care:pregnancy_tests
# >>>>>> human_services:health:medical_care:assistive_technology
# >>>>>> human_services:health:medical_care:prosthesis
# >>>>>> human_services:health:medical_care:counseling
# >>>>>> human_services:health:medical_care:disease_management
# >>>>>> human_services:health:medical_care:early_childhood_intervention
# >>>>>> human_services:health:medical_care:hiv_treatment
# >>>>>> human_services:health:medical_care:hospital_treatment
# >>>>>> human_services:health:medical_care:in_home_support
# >>>>>> human_services:health:medical_care:medication_management
# >>>>>> human_services:health:medical_care:nursing_home
# >>>>>> human_services:health:medical_care:occupational_therapy
# >>>>>> human_services:health:medical_care:outpatient_treatment
# >>>>>> human_services:health:medical_care:pain_management
# >>>>>> human_services:health:medical_care:physical_therapy
# >>>>>> human_services:health:medical_care:residential_treatment
# >>>>>> human_services:health:medical_care:specialized_therapy
# >>>>>> human_services:health:medical_care:speech_therapy
# >>>>>> human_services:health:medical_care:vaccinations
# >>>> human_services:health:mental_health_care
# >>>>>> human_services:health:mental_health_care:anger_management
# >>>>>> human_services:health:mental_health_care:bereavement
# >>>>>> human_services:health:mental_health_care:counseling
# >>>>>>>> human_services:health:mental_health_care:counseling:group_therapy
# >>>>>>>> human_services:health:mental_health_care:counseling:substance_abuse_counseling
# >>>>>>>> human_services:health:mental_health_care:counseling:family_counseling
# >>>>>>>> human_services:health:mental_health_care:counseling:individual_counseling
# >>>>>> human_services:health:mental_health_care:hospital_treatment
# >>>>>> human_services:health:mental_health_care:medications_for_mental_health
# >>>>>> human_services:health:mental_health_care:mental_health_evaluation
# >>>>>> human_services:health:mental_health_care:outpatient_treatment
# >>>>>> human_services:health:mental_health_care:psychiatric_emergency_services
# >>>>>> human_services:health:mental_health_care:residential_treatment
# >>>>>> human_services:health:mental_health_care:support_service_animals
# >>>>>> human_services:health:mental_health_care:understand_mental_health
# >>>>>> human_services:health:mental_health_care:group_therapy
# >>>>>> human_services:health:mental_health_care:substance_abuse_counseling
# >>>>>> human_services:health:mental_health_care:family_counseling
# >>>>>> human_services:health:mental_health_care:individual_counseling
# >>>> human_services:health:sexual_reproductive_health
# >>>>>> human_services:health:sexual_reproductive_health:family_planning
# >>>>>>>> human_services:health:sexual_reproductive_health:family_planning:birth_control
# >>>>>> human_services:health:sexual_reproductive_health:fertility
# >>>>>> human_services:health:sexual_reproductive_health:sex_education
# >>>>>> human_services:health:sexual_reproductive_health:std_sti_treatment_prevention
# >>>>>>>> human_services:health:sexual_reproductive_health:std_sti_treatment_prevention:hiv_treatment
# >>>>>> human_services:health:sexual_reproductive_health:women_s_health
# >>>>>>>> human_services:health:sexual_reproductive_health:women_s_health:maternity_care
# >>>>>>>> human_services:health:sexual_reproductive_health:women_s_health:postnatal_care
# >>>>>> human_services:health:sexual_reproductive_health:birth_control
# >>>>>> human_services:health:sexual_reproductive_health:hiv_treatment
# >>>>>> human_services:health:sexual_reproductive_health:maternity_care
# >>>>>> human_services:health:sexual_reproductive_health:postnatal_care
# >>>> human_services:health:vision_care
# >> human_services:money
# ddd: Services to help pay for housing, education, childcare, school, food and goods, financial education, tax preparation, insurance, government benefits, vouchers, and more.
# >>>> human_services:money:financial_assistance
# >>>>>> human_services:money:financial_assistance:help_pay_for_childcare
# >>>>>> human_services:money:financial_assistance:help_pay_for_food
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_food:government_food_benefits
# >>>>>> human_services:money:financial_assistance:help_pay_for_healthcare
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:disability_benefits
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:discounted_healthcare
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:health_insurance
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:medical_supplies
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:prescription_assistance
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_healthcare:transportation_for_healthcare
# >>>>>> human_services:money:financial_assistance:help_pay_for_housing
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_housing:help_pay_for_utilities
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_housing:help_pay_for_internet_or_phone
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_housing:home_renters_insurance
# >>>>>> human_services:money:financial_assistance:help_pay_for_school
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_school:books
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_school:clothes_for_school
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_school:financial_aid_loans
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_school:transportation_for_school
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_school:supplies_for_school
# >>>>>> human_services:money:financial_assistance:help_pay_for_transit
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_transit:bus_passes
# >>>>>>>> human_services:money:financial_assistance:help_pay_for_transit:help_pay_for_gas
# >>>>>> human_services:money:financial_assistance:help_pay_for_work_expenses
# >>>>>> human_services:money:financial_assistance:government_food_benefits
# >>>>>> human_services:money:financial_assistance:disability_benefits
# >>>>>> human_services:money:financial_assistance:discounted_healthcare
# >>>>>> human_services:money:financial_assistance:health_insurance
# >>>>>> human_services:money:financial_assistance:medical_supplies
# >>>>>> human_services:money:financial_assistance:prescription_assistance
# >>>>>> human_services:money:financial_assistance:transportation_for_healthcare
# >>>>>> human_services:money:financial_assistance:help_pay_for_utilities
# >>>>>> human_services:money:financial_assistance:help_pay_for_internet_or_phone
# >>>>>> human_services:money:financial_assistance:home_renters_insurance
# >>>>>> human_services:money:financial_assistance:books
# >>>>>> human_services:money:financial_assistance:clothes_for_school
# >>>>>> human_services:money:financial_assistance:financial_aid_loans
# >>>>>> human_services:money:financial_assistance:transportation_for_school
# >>>>>> human_services:money:financial_assistance:supplies_for_school
# >>>>>> human_services:money:financial_assistance:bus_passes
# >>>>>> human_services:money:financial_assistance:help_pay_for_gas
# >>>> human_services:money:government_benefits
# >>>>>> human_services:money:government_benefits:disability_benefits
# >>>>>> human_services:money:government_benefits:government_food_benefits
# >>>>>> human_services:money:government_benefits:retirement_benefits
# >>>>>> human_services:money:government_benefits:understand_government_programs
# >>>>>> human_services:money:government_benefits:unemployment_benefits
# >>>> human_services:money:financial_education
# >>>>>> human_services:money:financial_education:credit_counseling
# >>>>>> human_services:money:financial_education:foreclosure_counseling
# >>>>>> human_services:money:financial_education:homebuyer_education
# >>>>>> human_services:money:financial_education:savings_program
# >>>> human_services:money:insurance
# >>>>>> human_services:money:insurance:health_insurance
# >>>>>> human_services:money:insurance:home_renters_insurance
# >>>> human_services:money:loans
# >>>>>> human_services:money:loans:business_loans
# >>>>>> human_services:money:loans:personal_loans
# >>>> human_services:money:tax_preparation
# >> human_services:care
# ddd: Services for animal welfare, residential caregiving, daytime caregiving, adoption & foster care, building support networks, end-of-life care, and help navigating the system.
# >>>> human_services:care:adoption_foster_care
# >>>>>> human_services:care:adoption_foster_care:adoption_foster_placement
# >>>>>> human_services:care:adoption_foster_care:adoption_foster_parenting
# >>>>>> human_services:care:adoption_foster_care:adoption_planning
# >>>>>> human_services:care:adoption_foster_care:adoption_counseling
# >>>>>> human_services:care:adoption_foster_care:post_adoption_support
# >>>> human_services:care:animal_welfare
# >>>> human_services:care:community_support_services
# >>>>>> human_services:care:community_support_services:computer_or_internet_access
# >>>>>> human_services:care:community_support_services:exercise_fitness
# >>>>>> human_services:care:community_support_services:recreation
# >>>>>> human_services:care:community_support_services:weather_relief
# >>>> human_services:care:daytime_care
# >>>>>> human_services:care:daytime_care:adult_daycare
# >>>>>> human_services:care:daytime_care:after_school_care
# >>>>>> human_services:care:daytime_care:before_school_care
# >>>>>> human_services:care:daytime_care:childcare
# >>>>>>>> human_services:care:daytime_care:childcare:help_find_childcare
# >>>>>>>> human_services:care:daytime_care:childcare:help_pay_for_childcare
# >>>>>> human_services:care:daytime_care:day_camp
# >>>>>> human_services:care:daytime_care:early_childhood_intervention
# >>>>>> human_services:care:daytime_care:head_start
# >>>>>> human_services:care:daytime_care:preschool
# >>>>>> human_services:care:daytime_care:relief_for_caregivers
# >>>>>> human_services:care:daytime_care:help_find_childcare
# >>>>>> human_services:care:daytime_care:help_pay_for_childcare
# >>>> human_services:care:end_of_life_care
# >>>>>> human_services:care:end_of_life_care:bereavement
# >>>>>> human_services:care:end_of_life_care:burial_funeral_help
# >>>>>> human_services:care:end_of_life_care:hospice
# >>>> human_services:care:navigating_the_system
# >>>>>> human_services:care:navigating_the_system:help_fill_out_forms
# >>>>>> human_services:care:navigating_the_system:help_find_housing
# >>>>>> human_services:care:navigating_the_system:case_management
# >>>> human_services:care:physical_safety
# >>>>>> human_services:care:physical_safety:disaster_response
# >>>>>> human_services:care:physical_safety:emergency_food
# >>>>>> human_services:care:physical_safety:temporary_shelter
# >>>>>>>> human_services:care:physical_safety:temporary_shelter:weather_relief
# >>>>>> human_services:care:physical_safety:help_find_missing_persons
# >>>>>> human_services:care:physical_safety:immediate_safety
# >>>>>>>> human_services:care:physical_safety:immediate_safety:help_escape_violence
# >>>>>>>> human_services:care:physical_safety:immediate_safety:safe_housing
# >>>>>> human_services:care:physical_safety:safety_education
# >>>>>> human_services:care:physical_safety:weather_relief
# >>>>>> human_services:care:physical_safety:help_escape_violence
# >>>>>> human_services:care:physical_safety:safe_housing
# >>>> human_services:care:residential_care
# >>>>>> human_services:care:residential_care:assisted_living
# >>>>>> human_services:care:residential_care:residential_treatment
# >>>>>> human_services:care:residential_care:nursing_home
# >>>>>> human_services:care:residential_care:overnight_camp
# >>>> human_services:care:support_network
# >>>>>> human_services:care:support_network:counseling
# >>>>>> human_services:care:support_network:help_hotlines
# >>>>>> human_services:care:support_network:home_visiting
# >>>>>> human_services:care:support_network:in_home_support
# >>>>>> human_services:care:support_network:mentoring
# >>>>>> human_services:care:support_network:one_on_one_support
# >>>>>> human_services:care:support_network:peer_recovery_coaching
# >>>>>> human_services:care:support_network:peer_support
# >>>>>> human_services:care:support_network:spiritual_support
# >>>>>> human_services:care:support_network:support_groups
# >>>>>>>> human_services:care:support_network:support_groups:12_step
# >>>>>>>> human_services:care:support_network:support_groups:bereavement
# >>>>>>>> human_services:care:support_network:support_groups:parenting_education
# >>>>>> human_services:care:support_network:virtual_support
# >>>>>> human_services:care:support_network:12_step
# >>>>>> human_services:care:support_network:bereavement
# >>>>>> human_services:care:support_network:parenting_education
# >> human_services:education
# ddd: Services for preschool, after school, special education, help finding school, help paying for school, alternative education, tutoring, and more.
# >>>> human_services:education:help_find_school
# >>>> human_services:education:help_pay_for_school
# >>>>>> human_services:education:help_pay_for_school:books
# >>>>>> human_services:education:help_pay_for_school:clothes_for_school
# >>>>>> human_services:education:help_pay_for_school:financial_aid_loans
# >>>>>> human_services:education:help_pay_for_school:transportation_for_school
# >>>>>> human_services:education:help_pay_for_school:supplies_for_school
# >>>> human_services:education:more_education
# >>>>>> human_services:education:more_education:alternative_education
# >>>>>> human_services:education:more_education:civic_engagement
# >>>>>> human_services:education:more_education:college_readiness
# >>>>>> human_services:education:more_education:disaster_preparedness_response
# >>>>>> human_services:education:more_education:english_as_a_second_language_esl
# >>>>>> human_services:education:more_education:environmental_education
# >>>>>> human_services:education:more_education:financial_education
# >>>>>>>> human_services:education:more_education:financial_education:credit_counseling
# >>>>>>>> human_services:education:more_education:financial_education:foreclosure_counseling
# >>>>>>>> human_services:education:more_education:financial_education:homebuyer_education
# >>>>>> human_services:education:more_education:foreign_languages
# >>>>>> human_services:education:more_education:ged_high_school_equivalency
# >>>>>> human_services:education:more_education:health_education
# >>>>>>>> human_services:education:more_education:health_education:disease_management
# >>>>>>>> human_services:education:more_education:health_education:family_planning
# >>>>>>>> human_services:education:more_education:health_education:nutrition_education
# >>>>>>>> human_services:education:more_education:health_education:parenting_education
# >>>>>>>> human_services:education:more_education:health_education:safety_education
# >>>>>>>> human_services:education:more_education:health_education:sex_education
# >>>>>>>> human_services:education:more_education:health_education:understand_disability
# >>>>>>>> human_services:education:more_education:health_education:understand_mental_health
# >>>>>> human_services:education:more_education:supported_employment
# >>>>>> human_services:education:more_education:special_education
# >>>>>> human_services:education:more_education:tutoring
# >>>>>> human_services:education:more_education:youth_development
# >>>>>> human_services:education:more_education:credit_counseling
# >>>>>> human_services:education:more_education:foreclosure_counseling
# >>>>>> human_services:education:more_education:homebuyer_education
# >>>>>> human_services:education:more_education:disease_management
# >>>>>> human_services:education:more_education:family_planning
# >>>>>> human_services:education:more_education:nutrition_education
# >>>>>> human_services:education:more_education:parenting_education
# >>>>>> human_services:education:more_education:safety_education
# >>>>>> human_services:education:more_education:sex_education
# >>>>>> human_services:education:more_education:understand_disability
# >>>>>> human_services:education:more_education:understand_mental_health
# >>>> human_services:education:preschool
# >>>> human_services:education:screening_exams
# >>>>>> human_services:education:screening_exams:citizenship_immigration
# >>>>>> human_services:education:screening_exams:ged_high_school_equivalency
# >>>>>> human_services:education:screening_exams:english_as_a_second_language_esl
# >>>> human_services:education:skills_training
# >>>>>> human_services:education:skills_training:basic_literacy
# >>>>>> human_services:education:skills_training:computer_class
# >>>>>> human_services:education:skills_training:daily_life_skills
# >>>>>> human_services:education:skills_training:interview_training
# >>>>>> human_services:education:skills_training:resume_development
# >>>>>> human_services:education:skills_training:skills_assessment
# >>>>>> human_services:education:skills_training:specialized_training
# >> human_services:work
# ddd: Services for finding and sustaining work and improving job skills and abilities.
# >>>> human_services:work:help_find_work
# >>>>>> human_services:work:help_find_work:job_placement
# >>>>>> human_services:work:help_find_work:supported_employment
# >>>> human_services:work:help_pay_for_work_expenses
# >>>>>> human_services:work:help_pay_for_work_expenses:clothes_for_work
# >>>>>> human_services:work:help_pay_for_work_expenses:retirement_benefits
# >>>>>> human_services:work:help_pay_for_work_expenses:supplies_for_work
# >>>>>> human_services:work:help_pay_for_work_expenses:unemployment_benefits
# >>>> human_services:work:skills_training
# >>>>>> human_services:work:skills_training:basic_literacy
# >>>>>> human_services:work:skills_training:computer_class
# >>>>>> human_services:work:skills_training:ged_high_school_equivalency
# >>>>>> human_services:work:skills_training:interview_training
# >>>>>> human_services:work:skills_training:resume_development
# >>>>>> human_services:work:skills_training:skills_assessment
# >>>>>> human_services:work:skills_training:specialized_training
# >>>> human_services:work:supported_employment
# >>>> human_services:work:workplace_rights
# >> human_services:legal
# ddd: Services for legal representation, mediation, advocacy, citizenship and immigration, adoption and foster care, guardianship, civil rights, and more.
# >>>> human_services:legal:
# >>>>>> human_services:legal::advocacy_legal_aid
# >>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care
# >>>>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care:adoption_foster_placement
# >>>>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care:adoption_foster_parenting
# >>>>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care:adoption_planning
# >>>>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care:adoption_counseling
# >>>>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_care:post_adoption_support
# >>>>>>>> human_services:legal::advocacy_legal_aid:citizenship_immigration
# >>>>>>>> human_services:legal::advocacy_legal_aid:discrimination_civil_rights
# >>>>>>>> human_services:legal::advocacy_legal_aid:guardianship
# >>>>>>>> human_services:legal::advocacy_legal_aid:identification_recovery
# >>>>>>>> human_services:legal::advocacy_legal_aid:understand_government_programs
# >>>>>>>> human_services:legal::advocacy_legal_aid:workplace_rights
# >>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_placement
# >>>>>>>> human_services:legal::advocacy_legal_aid:adoption_foster_parenting
# >>>>>>>> human_services:legal::advocacy_legal_aid:adoption_planning
# >>>>>>>> human_services:legal::advocacy_legal_aid:adoption_counseling
# >>>>>>>> human_services:legal::advocacy_legal_aid:post_adoption_support
# >>>>>> human_services:legal::mediation
# >>>>>> human_services:legal::notary
# >>>>>> human_services:legal::representation
# >>>>>> human_services:legal::translation_interpretation
# >>>>>> human_services:legal::adoption_foster_care
# >>>>>>>> human_services:legal::adoption_foster_care:adoption_foster_placement
# >>>>>>>> human_services:legal::adoption_foster_care:adoption_foster_parenting
# >>>>>>>> human_services:legal::adoption_foster_care:adoption_planning
# >>>>>>>> human_services:legal::adoption_foster_care:adoption_counseling
# >>>>>>>> human_services:legal::adoption_foster_care:post_adoption_support
# >>>>>> human_services:legal::citizenship_immigration
# >>>>>> human_services:legal::discrimination_civil_rights
# >>>>>> human_services:legal::guardianship
# >>>>>> human_services:legal::identification_recovery
# >>>>>> human_services:legal::understand_government_programs
# >>>>>> human_services:legal::workplace_rights
# >>>>>> human_services:legal::adoption_foster_placement
# >>>>>> human_services:legal::adoption_foster_parenting
# >>>>>> human_services:legal::adoption_planning
# >>>>>> human_services:legal::adoption_counseling
# >>>>>> human_services:legal::post_adoption_support
# === human_situations
# ddd: These are common attributes about a person. These can be used to help match a person’s situation with available human services.
# >>>> human_situations:general
# >>>>>> human_situations:general:anyone_in_need
# >>>> human_situations:age_group
# >>>>>> human_situations:age_group:all_ages
# >>>>>> human_situations:age_group:adults_31_54_years_old
# >>>>>> human_situations:age_group:young_adults_20_30_years_old
# >>>>>> human_situations:age_group:teens_13_19_years_old
# >>>>>> human_situations:age_group:infants_0_1_years_old
# >>>>>> human_situations:age_group:children_2_12_years_old
# >>>>>> human_situations:age_group:seniors_55_years_old
# >>>> human_situations:armed_forces
# >>>>>> human_situations:armed_forces:active_duty
# >>>>>> human_situations:armed_forces:national_guard
# >>>>>> human_situations:armed_forces:veterans
# >>>> human_situations:citizenship
# >>>>>> human_situations:citizenship:immigrants
# >>>>>> human_situations:citizenship:refugees
# >>>>>> human_situations:citizenship:undocumented
# >>>> human_situations:justice_involvement
# >>>>>> human_situations:justice_involvement:criminal_justice_history
# >>>>>> human_situations:justice_involvement:in_jail
# >>>> human_situations:disability
# >>>>>> human_situations:disability:all_disabilities
# >>>>>> human_situations:disability:learning_disability
# >>>>>>>> human_situations:disability:learning_disability:add_adhd
# >>>>>> human_situations:disability:developmental_disability
# >>>>>> human_situations:disability:physical_disability
# >>>>>> human_situations:disability:intellectual_disability
# >>>>>> human_situations:disability:mentally_incapacitated
# >>>>>> human_situations:disability:limited_mobility
# >>>>>> human_situations:disability:deaf_or_hard_of_hearing
# >>>>>> human_situations:disability:visual_impairment
# >>>>>> human_situations:disability:add_adhd
# >>>> human_situations:education
# >>>>>> human_situations:education:dropouts
# >>>>>> human_situations:education:students
# >>>> human_situations:emotional_state
# >>>>>> human_situations:emotional_state:grieving
# >>>> human_situations:employment
# >>>>>> human_situations:employment:employed
# >>>>>> human_situations:employment:retirement
# >>>>>> human_situations:employment:unemployed
# >>>> human_situations:gender_identity
# >>>>>> human_situations:gender_identity:female
# >>>>>> human_situations:gender_identity:male
# >>>>>> human_situations:gender_identity:transgender_or_non_binary
# >>>>>> human_situations:gender_identity:lgbtqia
# >>>> human_situations:guardianship
# >>>>>> human_situations:guardianship:foster_youth
# >>>> human_situations:health
# >>>>>> human_situations:health:treatment_phases
# >>>>>>>> human_situations:health:treatment_phases:all_care_phases
# >>>>>>>> human_situations:health:treatment_phases:hospitalized
# >>>>>>>> human_situations:health:treatment_phases:recently_diagnosed
# >>>>>>>> human_situations:health:treatment_phases:on_treatment
# >>>>>>>> human_situations:health:treatment_phases:post_treatment
# >>>>>>>> human_situations:health:treatment_phases:facing_end_of_life
# >>>>>> human_situations:health:pregnant
# >>>>>> human_situations:health:cancer
# >>>>>>>> human_situations:health:cancer:all_cancer_types
# >>>>>>>> human_situations:health:cancer:bladder_cancer
# >>>>>>>> human_situations:health:cancer:brain_stem_glioma
# >>>>>>>> human_situations:health:cancer:brain_tumor
# >>>>>>>> human_situations:health:cancer:breast_cancer
# >>>>>>>> human_situations:health:cancer:central_nervous_system
# >>>>>>>> human_situations:health:cancer:cervical_cancer
# >>>>>>>> human_situations:health:cancer:colon_cancer
# >>>>>>>> human_situations:health:cancer:colorectal_cancer
# >>>>>>>> human_situations:health:cancer:desmoid_tumors
# >>>>>>>> human_situations:health:cancer:ductal_carcinoma_in_situ_dcis
# >>>>>>>> human_situations:health:cancer:endomentrial_cancer
# >>>>>>>> human_situations:health:cancer:gastrointestinal_stromal_tumors_gist
# >>>>>>>> human_situations:health:cancer:germ_cell_tumor
# >>>>>>>>>> human_situations:health:cancer:germ_cell_tumor:central_nervous_system_germ_cell_tumor
# >>>>>>>>>> human_situations:health:cancer:germ_cell_tumor:ovarian_germ_cell_tumor
# >>>>>>>>>> human_situations:health:cancer:germ_cell_tumor:testicular_germ_cell_tumor
# >>>>>>>> human_situations:health:cancer:head_neck_cancer
# >>>>>>>> human_situations:health:cancer:leukemia
# >>>>>>>>>> human_situations:health:cancer:leukemia:acute_lymphoblastic_leukemia_all
# >>>>>>>>>> human_situations:health:cancer:leukemia:acute_myeloid_leukemia_aml
# >>>>>>>>>> human_situations:health:cancer:leukemia:chronic_lymphocytic_leukemia_cll
# >>>>>>>>>> human_situations:health:cancer:leukemia:chronic_myelogenous_leukemia_cml
# >>>>>>>>>> human_situations:health:cancer:leukemia:hairy_cell_leukemia
# >>>>>>>> human_situations:health:cancer:liver_cancer
# >>>>>>>> human_situations:health:cancer:lung_cancer
# >>>>>>>>>> human_situations:health:cancer:lung_cancer:childhood_lung_cancer
# >>>>>>>>>> human_situations:health:cancer:lung_cancer:non_small_cell_lung_cancer
# >>>>>>>>>> human_situations:health:cancer:lung_cancer:small_cell_lung_cancer
# >>>>>>>> human_situations:health:cancer:lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:aids_related_lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:burkitt_lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:cutaneous_t_cell_lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:hodgkin_lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:non_hodgkin_lymphoma
# >>>>>>>>>> human_situations:health:cancer:lymphoma:primary_central_nervous_system_lymphoma_cns
# >>>>>>>> human_situations:health:cancer:myeloma_multiple
# >>>>>>>> human_situations:health:cancer:neuroblastoma
# >>>>>>>> human_situations:health:cancer:ovarian_cancer
# >>>>>>>> human_situations:health:cancer:rectal_cancer
# >>>>>>>> human_situations:health:cancer:sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:ewing_sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:kaposi_sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:osteosarcoma_sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:rhabdomyosarcoma_sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:soft_tissue_sarcoma
# >>>>>>>>>> human_situations:health:cancer:sarcoma:uterine_sarcoma
# >>>>>>>> human_situations:health:cancer:skin_cancer
# >>>>>>>>>> human_situations:health:cancer:skin_cancer:melanoma
# >>>>>>>> human_situations:health:cancer:stomach_gastric_cancer
# >>>>>>>> human_situations:health:cancer:testicular_cancer
# >>>>>>>> human_situations:health:cancer:throat_cancer
# >>>>>>>> human_situations:health:cancer:thyroid_cancer
# >>>>>>>> human_situations:health:cancer:vaginal_cancer
# >>>>>>>> human_situations:health:cancer:vulvar_cancer
# >>>>>>>> human_situations:health:cancer:wilms_tumor
# >>>>>>>> human_situations:health:cancer:central_nervous_system_germ_cell_tumor
# >>>>>>>> human_situations:health:cancer:ovarian_germ_cell_tumor
# >>>>>>>> human_situations:health:cancer:testicular_germ_cell_tumor
# >>>>>>>> human_situations:health:cancer:acute_lymphoblastic_leukemia_all
# >>>>>>>> human_situations:health:cancer:acute_myeloid_leukemia_aml
# >>>>>>>> human_situations:health:cancer:chronic_lymphocytic_leukemia_cll
# >>>>>>>> human_situations:health:cancer:chronic_myelogenous_leukemia_cml
# >>>>>>>> human_situations:health:cancer:hairy_cell_leukemia
# >>>>>>>> human_situations:health:cancer:childhood_lung_cancer
# >>>>>>>> human_situations:health:cancer:non_small_cell_lung_cancer
# >>>>>>>> human_situations:health:cancer:small_cell_lung_cancer
# >>>>>>>> human_situations:health:cancer:aids_related_lymphoma
# >>>>>>>> human_situations:health:cancer:burkitt_lymphoma
# >>>>>>>> human_situations:health:cancer:cutaneous_t_cell_lymphoma
# >>>>>>>> human_situations:health:cancer:hodgkin_lymphoma
# >>>>>>>> human_situations:health:cancer:non_hodgkin_lymphoma
# >>>>>>>> human_situations:health:cancer:primary_central_nervous_system_lymphoma_cns
# >>>>>>>> human_situations:health:cancer:ewing_sarcoma
# >>>>>>>> human_situations:health:cancer:kaposi_sarcoma
# >>>>>>>> human_situations:health:cancer:osteosarcoma_sarcoma
# >>>>>>>> human_situations:health:cancer:rhabdomyosarcoma_sarcoma
# >>>>>>>> human_situations:health:cancer:soft_tissue_sarcoma
# >>>>>>>> human_situations:health:cancer:uterine_sarcoma
# >>>>>>>> human_situations:health:cancer:melanoma
# >>>>>> human_situations:health:alzheimer_s
# >>>>>> human_situations:health:seizures
# >>>>>> human_situations:health:terminal_illness
# >>>>>> human_situations:health:infectious_disease
# >>>>>>>> human_situations:health:infectious_disease:hiv_aids
# >>>>>> human_situations:health:neuromuscular_disease
# >>>>>> human_situations:health:all_mental_health
# >>>>>> human_situations:health:chronic_illness
# >>>>>> human_situations:health:genetic_disorder
# >>>>>> human_situations:health:diabetes
# >>>>>> human_situations:health:autism
# >>>>>> human_situations:health:all_care_phases
# >>>>>> human_situations:health:hospitalized
# >>>>>> human_situations:health:recently_diagnosed
# >>>>>> human_situations:health:on_treatment
# >>>>>> human_situations:health:post_treatment
# >>>>>> human_situations:health:facing_end_of_life
# >>>>>> human_situations:health:all_cancer_types
# >>>>>> human_situations:health:bladder_cancer
# >>>>>> human_situations:health:brain_stem_glioma
# >>>>>> human_situations:health:brain_tumor
# >>>>>> human_situations:health:breast_cancer
# >>>>>> human_situations:health:central_nervous_system
# >>>>>> human_situations:health:cervical_cancer
# >>>>>> human_situations:health:colon_cancer
# >>>>>> human_situations:health:colorectal_cancer
# >>>>>> human_situations:health:desmoid_tumors
# >>>>>> human_situations:health:ductal_carcinoma_in_situ_dcis
# >>>>>> human_situations:health:endomentrial_cancer
# >>>>>> human_situations:health:gastrointestinal_stromal_tumors_gist
# >>>>>> human_situations:health:germ_cell_tumor
# >>>>>>>> human_situations:health:germ_cell_tumor:central_nervous_system_germ_cell_tumor
# >>>>>>>> human_situations:health:germ_cell_tumor:ovarian_germ_cell_tumor
# >>>>>>>> human_situations:health:germ_cell_tumor:testicular_germ_cell_tumor
# >>>>>> human_situations:health:head_neck_cancer
# >>>>>> human_situations:health:leukemia
# >>>>>>>> human_situations:health:leukemia:acute_lymphoblastic_leukemia_all
# >>>>>>>> human_situations:health:leukemia:acute_myeloid_leukemia_aml
# >>>>>>>> human_situations:health:leukemia:chronic_lymphocytic_leukemia_cll
# >>>>>>>> human_situations:health:leukemia:chronic_myelogenous_leukemia_cml
# >>>>>>>> human_situations:health:leukemia:hairy_cell_leukemia
# >>>>>> human_situations:health:liver_cancer
# >>>>>> human_situations:health:lung_cancer
# >>>>>>>> human_situations:health:lung_cancer:childhood_lung_cancer
# >>>>>>>> human_situations:health:lung_cancer:non_small_cell_lung_cancer
# >>>>>>>> human_situations:health:lung_cancer:small_cell_lung_cancer
# >>>>>> human_situations:health:lymphoma
# >>>>>>>> human_situations:health:lymphoma:aids_related_lymphoma
# >>>>>>>> human_situations:health:lymphoma:burkitt_lymphoma
# >>>>>>>> human_situations:health:lymphoma:cutaneous_t_cell_lymphoma
# >>>>>>>> human_situations:health:lymphoma:hodgkin_lymphoma
# >>>>>>>> human_situations:health:lymphoma:non_hodgkin_lymphoma
# >>>>>>>> human_situations:health:lymphoma:primary_central_nervous_system_lymphoma_cns
# >>>>>> human_situations:health:myeloma_multiple
# >>>>>> human_situations:health:neuroblastoma
# >>>>>> human_situations:health:ovarian_cancer
# >>>>>> human_situations:health:rectal_cancer
# >>>>>> human_situations:health:sarcoma
# >>>>>>>> human_situations:health:sarcoma:ewing_sarcoma
# >>>>>>>> human_situations:health:sarcoma:kaposi_sarcoma
# >>>>>>>> human_situations:health:sarcoma:osteosarcoma_sarcoma
# >>>>>>>> human_situations:health:sarcoma:rhabdomyosarcoma_sarcoma
# >>>>>>>> human_situations:health:sarcoma:soft_tissue_sarcoma
# >>>>>>>> human_situations:health:sarcoma:uterine_sarcoma
# >>>>>> human_situations:health:skin_cancer
# >>>>>>>> human_situations:health:skin_cancer:melanoma
# >>>>>> human_situations:health:stomach_gastric_cancer
# >>>>>> human_situations:health:testicular_cancer
# >>>>>> human_situations:health:throat_cancer
# >>>>>> human_situations:health:thyroid_cancer
# >>>>>> human_situations:health:vaginal_cancer
# >>>>>> human_situations:health:vulvar_cancer
# >>>>>> human_situations:health:wilms_tumor
# >>>>>> human_situations:health:central_nervous_system_germ_cell_tumor
# >>>>>> human_situations:health:ovarian_germ_cell_tumor
# >>>>>> human_situations:health:testicular_germ_cell_tumor
# >>>>>> human_situations:health:acute_lymphoblastic_leukemia_all
# >>>>>> human_situations:health:acute_myeloid_leukemia_aml
# >>>>>> human_situations:health:chronic_lymphocytic_leukemia_cll
# >>>>>> human_situations:health:chronic_myelogenous_leukemia_cml
# >>>>>> human_situations:health:hairy_cell_leukemia
# >>>>>> human_situations:health:childhood_lung_cancer
# >>>>>> human_situations:health:non_small_cell_lung_cancer
# >>>>>> human_situations:health:small_cell_lung_cancer
# >>>>>> human_situations:health:aids_related_lymphoma
# >>>>>> human_situations:health:burkitt_lymphoma
# >>>>>> human_situations:health:cutaneous_t_cell_lymphoma
# >>>>>> human_situations:health:hodgkin_lymphoma
# >>>>>> human_situations:health:non_hodgkin_lymphoma
# >>>>>> human_situations:health:primary_central_nervous_system_lymphoma_cns
# >>>>>> human_situations:health:ewing_sarcoma
# >>>>>> human_situations:health:kaposi_sarcoma
# >>>>>> human_situations:health:osteosarcoma_sarcoma
# >>>>>> human_situations:health:rhabdomyosarcoma_sarcoma
# >>>>>> human_situations:health:soft_tissue_sarcoma
# >>>>>> human_situations:health:uterine_sarcoma
# >>>>>> human_situations:health:melanoma
# >>>>>> human_situations:health:hiv_aids
# >>>> human_situations:household
# >>>>>> human_situations:household:individuals
# >>>>>> human_situations:household:families
# >>>>>>>> human_situations:household:families:with_children
# >>>>>>>> human_situations:household:families:single_parent
# >>>>>> human_situations:household:with_children
# >>>>>> human_situations:household:single_parent
# >>>> human_situations:housing
# >>>>>> human_situations:housing:home_owners
# >>>>>> human_situations:housing:home_renters
# >>>>>> human_situations:housing:homeless
# >>>>>> human_situations:housing:near_homeless
# >>>>>> human_situations:housing:runaways
# >>>> human_situations:income
# >>>>>> human_situations:income:benefit_recipients
# >>>>>> human_situations:income:low_income
# >>>> human_situations:insurance
# >>>>>> human_situations:insurance:uninsured
# >>>>>> human_situations:insurance:underinsured
# >>>> human_situations:language
# >>>>>> human_situations:language:limited_english
# >>>> human_situations:mental_health
# >>>>>> human_situations:mental_health:anxiety
# >>>>>> human_situations:mental_health:bipolar
# >>>>>> human_situations:mental_health:brain_injury
# >>>>>> human_situations:mental_health:depression
# >>>>>> human_situations:mental_health:eating_disorder
# >>>>>> human_situations:mental_health:suicidal_thoughts
# >>>> human_situations:race_ethnicity
# >>>>>> human_situations:race_ethnicity:african_american
# >>>>>> human_situations:race_ethnicity:asian
# >>>>>> human_situations:race_ethnicity:latino
# >>>>>> human_situations:race_ethnicity:native_american
# >>>> human_situations:role
# >>>>>> human_situations:role:caregivers
# >>>>>> human_situations:role:spouses
# >>>>>> human_situations:role:dependents
# >>>>>> human_situations:role:fathers
# >>>>>> human_situations:role:mothers
# >>>>>> human_situations:role:parents
# >>>> human_situations:substance_dependency
# >>>>>> human_situations:substance_dependency:alcohol_dependency
# >>>>>> human_situations:substance_dependency:dual_diagnosis
# >>>>>> human_situations:substance_dependency:opioid_dependency
# >>>>>> human_situations:substance_dependency:smoker
# >>>> human_situations:sexual_orientation_identity
# >>>>>> human_situations:sexual_orientation_identity:lgbtq
# >>>>>> human_situations:sexual_orientation_identity:transgender
# >>>> human_situations:survivors
# >>>>>> human_situations:survivors:trauma_survivors
# >>>>>> human_situations:survivors:abuse_or_neglect_survivors
# >>>>>> human_situations:survivors:burn_survivors
# >>>>>> human_situations:survivors:all_cancer_survivors
# >>>>>> human_situations:survivors:childhood_cancer_survivors
# >>>>>> human_situations:survivors:young_adult_cancer_survivors
# >>>>>> human_situations:survivors:adult_cancer_survivors
# >>>>>> human_situations:survivors:domestic_violence_survivors
# >>>>>> human_situations:survivors:human_trafficking_survivors
# >>>>>> human_situations:survivors:natural_disaster_survivors
# >>>>>> human_situations:survivors:sexual_assault_survivors
# >>>> human_situations:urgency
# >>>>>> human_situations:urgency:in_crisis
# >>>>>> human_situations:urgency:in_danger
# >>>>>> human_situations:urgency:emergency

# %% [markdown]
# ### Load and parse data from https://github.com/auntbertha/openeligibility/blob/master/taxonomy

# %%
from lxml import etree
import requests
from io import StringIO

content = open('../taxonomy', 'rb').read()
content = content.replace(b'version="2.0"', b'version="1.0"')
tree = etree.fromstring(content)

checks_map = dict()

for top in tree.iterchildren():
    if top.tag in ('services', 'situations'):
        checks = checks_map.setdefault(top.tag, [])
        desc=dict()
        for el1 in top.iterchildren():
            if el1.tag == 'descriptions':
                for el2 in el1.iterchildren():
                    desc[el2.attrib['id']] = el2.text.strip()
        for el1 in top.iterchildren():
            if el1.tag == 'top_level':
                checks.append(([el1.attrib['title']], desc.get(el1.attrib['id'])))
#                 out.write(el1.attrib['title'] + ',,,"' + desc.get(el1.attrib['id'], '') + '"\n')
                for el2 in el1.iterchildren():
                    if el2.tag == 'second_level':
                        checks.append(([el1.attrib['title'], el2.attrib['title']],))
                        for el3 in el2.iterchildren():
                            if el3.tag == 'third_level':
                                checks.append(([el1.attrib['title'], el2.attrib['title'], el3.attrib['title']],))
                                for el4 in el3.iterchildren():
                                    if el4.tag == 'fourth_level':
                                        checks.append(([el1.attrib['title'], el2.attrib['title'], el3.attrib['title'], el3.attrib['title']],))

print(checks)
# Out:
# [(['General'], None), (['General', 'Anyone in Need'],), (['Age Group'], None), (['Age Group', 'Adults'],), (['Age Group', 'Teens'],), (['Age Group', 'Children'],), (['Age Group', 'Seniors'],), (['Armed Forces'], None), (['Armed Forces', 'Active Duty'],), (['Armed Forces', 'National Guard'],), (['Armed Forces', 'Veterans'],), (['Citizenship'], None), (['Citizenship', 'Immigrants'],), (['Citizenship', 'Refugees'],), (['Citizenship', 'Undocumented'],), (['Criminal History'], None), (['Criminal History', 'Ex-Offenders'],), (['Disability'], None), (['Disability', 'Learning Disability'],), (['Disability', 'Developmental Disability'],), (['Disability', 'Physical Disability'],), (['Disability', 'Intellectual Disability'],), (['Disability', 'Mentally Incapacitated'],), (['Disability', 'Limited Mobility'],), (['Disability', 'Hearing Impairment'],), (['Disability', 'Visual Impairment'],), (['Disability', 'Mental Illness'],), (['Education'], None), (['Education', 'Dropouts'],), (['Education', 'Students'],), (['Emotional State'], None), (['Emotional State', 'Grieving'],), (['Employment'], None), (['Employment', 'Employed'],), (['Employment', 'Retirement'],), (['Employment', 'Unemployed'],), (['Gender'], None), (['Gender', 'Women'],), (['Gender', 'Men'],), (['Gender', 'Transgender'],), (['Guardianship'], None), (['Guardianship', 'Foster Youth'],), (['Health'], None), (['Health', 'Hospitalized'],), (['Health', 'Pregnant'],), (['Health', 'Cancer'],), (['Health', 'Alzheimers'],), (['Health', 'Seizure Disorder'],), (['Health', 'Terminal Illness'],), (['Health', 'Infectious Disease'],), (['Health', 'Neuromuscular Disease'],), (['Health', 'Substance Dependency'],), (['Health', 'Mental Illness'],), (['Health', 'Chronic Illness'],), (['Household'], None), (['Household', 'Individuals'],), (['Household', 'Families'],), (['Housing'], None), (['Housing', 'Home Owners'],), (['Housing', 'Home Renters'],), (['Housing', 'Homeless'],), (['Housing', 'Near Homeless'],), (['Housing', 'Runaways'],), (['Income'], None), (['Income', 'Benefit Recipients'],), (['Income', 'Low-Income'],), (['Insurance'], None), (['Insurance', 'Uninsured'],), (['Language'], None), (['Language', 'Limited English'],), (['Race/Ethnicity'], None), (['Race/Ethnicity', 'African American'],), (['Race/Ethnicity', 'Asian'],), (['Race/Ethnicity', 'Latino'],), (['Role'], None), (['Role', 'Caregivers'],), (['Role', 'Spouses'],), (['Role', 'Dependents'],), (['Role', 'Fathers'],), (['Role', 'Mothers'],), (['Role', 'Parents'],), (['Sexuality'], None), (['Sexuality', 'LGBTQ'],), (['Survivors'], None), (['Survivors', 'All Survivors'],), (['Survivors', 'Abuse or Neglect Survivors'],), (['Survivors', 'Burn Survivors'],), (['Survivors', 'Domestic Violence Survivors'],), (['Survivors', 'Human Trafficking Survivors'],), (['Survivors', 'Natural Disaster Survivors'],), (['Survivors', 'Sexual Assault Survivors'],), (['Urgency'], None), (['Urgency', 'In Crisis'],), (['Urgency', 'In Danger'],)]

# %% [markdown]
# ### Consolidate the two sources

# %%
for tag, checks in checks_map.items():
    tree = sections[dict(services=0, situations=1)[tag]]
    for check in checks:
        node = tree
        for i, c in enumerate(check[0]):
            nodes = [n for n in node.setdefault('items', []) if n['name'] == c]
            if len(nodes) == 0:
                print('MISSING', tag, check)
                _node = get_item(node['slug'], c)
                node['items'].append(_node)
                node = _node
            else:
                node = nodes[0]
# Out:
# MISSING services (['Emergency'], 'Services for psychiatric emergencies, emergency financial assistance, immediate safety needs, disaster preparedness and disaster response.')
# MISSING services (['Emergency', 'Disaster Response'],)
# MISSING services (['Emergency', 'Emergency Payments'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for Food'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for Healthcare'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for Housing'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for Gas'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for School'],)
# MISSING services (['Emergency', 'Emergency Payments', 'Help Pay for Utilities'],)
# MISSING services (['Emergency', 'Emergency Food'],)
# MISSING services (['Emergency', 'Emergency Shelter'],)
# MISSING services (['Emergency', 'Help Find Missing Persons'],)
# MISSING services (['Emergency', 'Immediate Safety'],)
# MISSING services (['Emergency', 'Immediate Safety', 'Help Escape Violence'],)
# MISSING services (['Emergency', 'Immediate Safety', 'Safe Housing'],)
# MISSING services (['Emergency', 'Psychiatric Emergency Services'],)
# MISSING services (['Food'], 'Services for free meals, food pantries, help paying for food, food delivery, food benefits and nutrition support.')
# MISSING services (['Food', 'Community Gardens'],)
# MISSING services (['Food', 'Emergency Food'],)
# MISSING services (['Food', 'Food Delivery'],)
# MISSING services (['Food', 'Food Pantry'],)
# MISSING services (['Food', 'Free Meals'],)
# MISSING services (['Food', 'Help Pay for Food'],)
# MISSING services (['Food', 'Help Pay for Food', 'Food Benefits'],)
# MISSING services (['Food', 'Nutrition'],)
# MISSING services (['Housing'], 'Services for emergency, short-term and long-term housing, housing advice, help finding housing and help paying for housing.')
# MISSING services (['Housing', 'Emergency Shelter'],)
# MISSING services (['Housing', 'Help Find Housing'],)
# MISSING services (['Housing', 'Help Pay for Housing'],)
# MISSING services (['Housing', 'Help Pay for Housing', 'Help Pay for Utilities'],)
# MISSING services (['Housing', 'Help Pay for Housing', 'Home & Renters Insurance'],)
# MISSING services (['Housing', 'Help Pay for Housing', 'Housing Vouchers'],)
# MISSING services (['Housing', 'Help Pay for Housing', 'Maintenance & Repairs'],)
# MISSING services (['Housing', 'Housing Advice'],)
# MISSING services (['Housing', 'Housing Advice', 'Foreclosure Counseling'],)
# MISSING services (['Housing', 'Housing Advice', 'Homebuyer Education'],)
# MISSING services (['Housing', 'Residential Housing'],)
# MISSING services (['Housing', 'Residential Housing', 'Long-Term Housing'],)
# MISSING services (['Housing', 'Residential Housing', 'Long-Term Housing', 'Long-Term Housing'],)
# MISSING services (['Housing', 'Residential Housing', 'Safe Housing'],)
# MISSING services (['Housing', 'Residential Housing', 'Short-Term Housing'],)
# MISSING services (['Housing', 'Residential Housing', 'Short-Term Housing', 'Short-Term Housing'],)
# MISSING services (['Goods'], 'Services for clothing, furniture, baby supplies, toys and gifts and other physical goods.')
# MISSING services (['Goods', 'Baby Supplies'],)
# MISSING services (['Goods', 'Baby Supplies', 'Baby Clothes'],)
# MISSING services (['Goods', 'Baby Supplies', 'Diapers & Formula'],)
# MISSING services (['Goods', 'Clothing'],)
# MISSING services (['Goods', 'Clothing', 'Baby Clothes'],)
# MISSING services (['Goods', 'Clothing', 'Clothes for School'],)
# MISSING services (['Goods', 'Clothing', 'Clothes for Work'],)
# MISSING services (['Goods', 'Clothing', 'Clothing Vouchers'],)
# MISSING services (['Goods', 'Home Goods'],)
# MISSING services (['Goods', 'Home Goods', 'Blankets & Fans'],)
# MISSING services (['Goods', 'Home Goods', 'Books'],)
# MISSING services (['Goods', 'Home Goods', 'Furniture'],)
# MISSING services (['Goods', 'Home Goods', 'Personal Care Items'],)
# MISSING services (['Goods', 'Home Goods', 'Supplies for Work'],)
# MISSING services (['Goods', 'Medical Supplies'],)
# MISSING services (['Goods', 'Toys & Gifts'],)
# MISSING services (['Transit'], 'Services for bus passes, transportation to school, healthcare, appointments and more.')
# MISSING services (['Transit', 'Help Pay for Transit'],)
# MISSING services (['Transit', 'Help Pay for Transit', 'Bus Passes'],)
# MISSING services (['Transit', 'Help Pay for Transit', 'Help Pay for Gas'],)
# MISSING services (['Transit', 'Transportation'],)
# MISSING services (['Transit', 'Transportation', 'Transportation for Healthcare'],)
# MISSING services (['Transit', 'Transportation', 'Transportation for School'],)
# MISSING services (['Health'], 'Services for medical care, dental care, health education, addiction and recovery, help finding services and help paying for healthcare.')
# MISSING services (['Health', 'Addiction & Recovery'],)
# MISSING services (['Health', 'Addiction & Recovery', '12-Step'],)
# MISSING services (['Health', 'Addiction & Recovery', 'Detox'],)
# MISSING services (['Health', 'Addiction & Recovery', 'Outpatient Treatment'],)
# MISSING services (['Health', 'Addiction & Recovery', 'Residential Treatment'],)
# MISSING services (['Health', 'Addiction & Recovery', 'Sober Living'],)
# MISSING services (['Health', 'Dental Care'],)
# MISSING services (['Health', 'End-of-Life Care'],)
# MISSING services (['Health', 'End-of-Life Care', 'Bereavement'],)
# MISSING services (['Health', 'End-of-Life Care', 'Burial & Funeral Help'],)
# MISSING services (['Health', 'End-of-Life Care', 'Hospice'],)
# MISSING services (['Health', 'End-of-Life Care', 'Pain Management'],)
# MISSING services (['Health', 'Health Education'],)
# MISSING services (['Health', 'Health Education', 'Daily Life Skills'],)
# MISSING services (['Health', 'Health Education', 'Disease Management'],)
# MISSING services (['Health', 'Health Education', 'Family Planning'],)
# MISSING services (['Health', 'Health Education', 'Nutrition'],)
# MISSING services (['Health', 'Health Education', 'Parenting Education'],)
# MISSING services (['Health', 'Health Education', 'Sex Education'],)
# MISSING services (['Health', 'Health Education', 'Understand Disability'],)
# MISSING services (['Health', 'Health Education', 'Understand Mental Health'],)
# MISSING services (['Health', 'Help Pay for Healthcare'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Disability Benefits'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Discounted Healthcare'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Health Insurance'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Medical Supplies'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Prescription Assistance'],)
# MISSING services (['Health', 'Help Pay for Healthcare', 'Transportation for Healthcare'],)
# MISSING services (['Health', 'Medical Care'],)
# MISSING services (['Health', 'Medical Care', 'Primary Care'],)
# MISSING services (['Health', 'Medical Care', 'Alternative Medicine'],)
# MISSING services (['Health', 'Medical Care', 'Assistive Technology'],)
# MISSING services (['Health', 'Medical Care', 'Birth Control'],)
# MISSING services (['Health', 'Medical Care', 'Checkup & Test'],)
# MISSING services (['Health', 'Medical Care', 'Checkup & Test', 'Checkup & Test'],)
# MISSING services (['Health', 'Medical Care', 'Maternity Care'],)
# MISSING services (['Health', 'Medical Care', 'Personal Hygiene'],)
# MISSING services (['Health', 'Medical Care', 'Prevent & Treat'],)
# MISSING services (['Health', 'Medical Care', 'Prevent & Treat', 'Prevent & Treat'],)
# MISSING services (['Health', 'Medical Care', 'Psychiatric Emergency Services'],)
# MISSING services (['Money'], 'Services to help pay for housing, education, childcare, school, food and goods, financial education, tax preparation, insurance, government benefits, vouchers and more.')
# MISSING services (['Money', 'Financial Assistance'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Childcare'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Food'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Food', 'Help Pay for Food'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Healthcare'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Healthcare', 'Help Pay for Healthcare'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Housing'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Housing', 'Help Pay for Housing'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for School'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for School', 'Help Pay for School'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Transit'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Transit', 'Help Pay for Transit'],)
# MISSING services (['Money', 'Financial Assistance', 'Help Pay for Work Expenses'],)
# MISSING services (['Money', 'Government Benefits'],)
# MISSING services (['Money', 'Government Benefits', 'Disability Benefits'],)
# MISSING services (['Money', 'Government Benefits', 'Food Benefits'],)
# MISSING services (['Money', 'Government Benefits', 'Retirement Benefits'],)
# MISSING services (['Money', 'Government Benefits', 'Understand Government Programs'],)
# MISSING services (['Money', 'Government Benefits', 'Unemployment Benefits'],)
# MISSING services (['Money', 'Financial Education'],)
# MISSING services (['Money', 'Financial Education', 'Credit Counseling'],)
# MISSING services (['Money', 'Financial Education', 'Foreclosure Counseling'],)
# MISSING services (['Money', 'Financial Education', 'Homebuyer Education'],)
# MISSING services (['Money', 'Financial Education', 'Savings Program'],)
# MISSING services (['Money', 'Insurance'],)
# MISSING services (['Money', 'Insurance', 'Health Insurance'],)
# MISSING services (['Money', 'Insurance', 'Home & Renters Insurance'],)
# MISSING services (['Money', 'Tax Preparation'],)
# MISSING services (['Care'], 'Services for animal welfare, residential caregiving, daytime caregiving, adoption & foster care, building support networks, end-of-life care and help navigating the system.')
# MISSING services (['Care', 'Adoption & Foster Care'],)
# MISSING services (['Care', 'Adoption & Foster Care', 'Adoption & Foster Placement'],)
# MISSING services (['Care', 'Adoption & Foster Care', 'Adoption & Foster Parenting'],)
# MISSING services (['Care', 'Adoption & Foster Care', 'Adoption Planning'],)
# MISSING services (['Care', 'Adoption & Foster Care', 'Post-Adoption Support'],)
# MISSING services (['Care', 'Animal Welfare'],)
# MISSING services (['Care', 'Daytime Care'],)
# MISSING services (['Care', 'Daytime Care', 'Adult Daycare'],)
# MISSING services (['Care', 'Daytime Care', 'Afterschool Care'],)
# MISSING services (['Care', 'Daytime Care', 'Childcare'],)
# MISSING services (['Care', 'Daytime Care', 'Childcare', 'Childcare'],)
# MISSING services (['Care', 'Daytime Care', 'Day Camp'],)
# MISSING services (['Care', 'Daytime Care', 'Preschool'],)
# MISSING services (['Care', 'Daytime Care', 'Recreation'],)
# MISSING services (['Care', 'Daytime Care', 'Relief for Caregivers'],)
# MISSING services (['Care', 'End-of-Life Care'],)
# MISSING services (['Care', 'End-of-Life Care', 'Bereavement'],)
# MISSING services (['Care', 'End-of-Life Care', 'Burial & Funeral Help'],)
# MISSING services (['Care', 'End-of-Life Care', 'Hospice'],)
# MISSING services (['Care', 'End-of-Life Care', 'Pain Management'],)
# MISSING services (['Care', 'Navigating the System'],)
# MISSING services (['Care', 'Navigating the System', 'Help Fill out Forms'],)
# MISSING services (['Care', 'Navigating the System', 'Help Find Childcare'],)
# MISSING services (['Care', 'Navigating the System', 'Help Find Housing'],)
# MISSING services (['Care', 'Navigating the System', 'Help Find School'],)
# MISSING services (['Care', 'Navigating the System', 'Help Find Work'],)
# MISSING services (['Care', 'Residential Care'],)
# MISSING services (['Care', 'Residential Care', 'Assisted Living'],)
# MISSING services (['Care', 'Residential Care', 'Residential Treatment'],)
# MISSING services (['Care', 'Residential Care', 'Nursing Home'],)
# MISSING services (['Care', 'Residential Care', 'Overnight Camp'],)
# MISSING services (['Care', 'Support Network'],)
# MISSING services (['Care', 'Support Network', 'Counseling'],)
# MISSING services (['Care', 'Support Network', 'Help Hotlines'],)
# MISSING services (['Care', 'Support Network', 'Home Visiting'],)
# MISSING services (['Care', 'Support Network', 'In-Home Support'],)
# MISSING services (['Care', 'Support Network', 'Mentoring'],)
# MISSING services (['Care', 'Support Network', 'One-on-One Support'],)
# MISSING services (['Care', 'Support Network', 'Peer Support'],)
# MISSING services (['Care', 'Support Network', 'Spiritual Support'],)
# MISSING services (['Care', 'Support Network', 'Support Groups'],)
# MISSING services (['Care', 'Support Network', 'Support Groups', 'Support Groups'],)
# MISSING services (['Care', 'Support Network', 'Virtual Support'],)
# MISSING services (['Education'], 'Services for preschool, after-school, special education, help finding school, help paying for school, alternative education tutoring and more.')
# MISSING services (['Education', 'Help Find School'],)
# MISSING services (['Education', 'Help Pay for School'],)
# MISSING services (['Education', 'Help Pay for School', 'Books'],)
# MISSING services (['Education', 'Help Pay for School', 'Clothes for School'],)
# MISSING services (['Education', 'Help Pay for School', 'Financial Aid & Loans'],)
# MISSING services (['Education', 'Help Pay for School', 'Transportation for School'],)
# MISSING services (['Education', 'More Education'],)
# MISSING services (['Education', 'More Education', 'Alternative Education'],)
# MISSING services (['Education', 'More Education', 'Disaster Preparedness & Response'],)
# MISSING services (['Education', 'More Education', 'English as a Second Language (ESL)'],)
# MISSING services (['Education', 'More Education', 'Financial Education'],)
# MISSING services (['Education', 'More Education', 'Financial Education', 'Financial Education'],)
# MISSING services (['Education', 'More Education', 'Foreign Languages'],)
# MISSING services (['Education', 'More Education', 'GED/High-School Equivalency'],)
# MISSING services (['Education', 'More Education', 'Health Education'],)
# MISSING services (['Education', 'More Education', 'Health Education', 'Health Education'],)
# MISSING services (['Education', 'More Education', 'Supported Employment'],)
# MISSING services (['Education', 'More Education', 'Special Education'],)
# MISSING services (['Education', 'More Education', 'Tutoring'],)
# MISSING services (['Education', 'Preschool'],)
# MISSING services (['Education', 'Screening & Exams'],)
# MISSING services (['Education', 'Screening & Exams', 'Citizenship & Immigration'],)
# MISSING services (['Education', 'Screening & Exams', 'GED/High-School Equivalency'],)
# MISSING services (['Education', 'Screening & Exams', 'English as a Second Language (ESL)'],)
# MISSING services (['Education', 'Skills & Training'],)
# MISSING services (['Education', 'Skills & Training', 'Basic Literacy'],)
# MISSING services (['Education', 'Skills & Training', 'Computer Class'],)
# MISSING services (['Education', 'Skills & Training', 'Daily Life Skills'],)
# MISSING services (['Education', 'Skills & Training', 'Interview Training'],)
# MISSING services (['Education', 'Skills & Training', 'Resume Development'],)
# MISSING services (['Education', 'Skills & Training', 'Skills Assessment'],)
# MISSING services (['Education', 'Skills & Training', 'Specialized Training'],)
# MISSING services (['Work'], 'Services for finding and sustaining work and improving job skills and abilities.')
# MISSING services (['Work', 'Help Find Work'],)
# MISSING services (['Work', 'Help Find Work', 'Job Placement'],)
# MISSING services (['Work', 'Help Find Work', 'Supported Employment'],)
# MISSING services (['Work', 'Help Pay for Work Expenses'],)
# MISSING services (['Work', 'Help Pay for Work Expenses', 'Clothes for Work'],)
# MISSING services (['Work', 'Help Pay for Work Expenses', 'Retirement Benefits'],)
# MISSING services (['Work', 'Help Pay for Work Expenses', 'Supplies for Work'],)
# MISSING services (['Work', 'Help Pay for Work Expenses', 'Unemployment Benefits'],)
# MISSING services (['Work', 'Skills & Training'],)
# MISSING services (['Work', 'Skills & Training', 'Basic Literacy'],)
# MISSING services (['Work', 'Skills & Training', 'Computer Class'],)
# MISSING services (['Work', 'Skills & Training', 'GED/High-School Equivalency'],)
# MISSING services (['Work', 'Skills & Training', 'Interview Training'],)
# MISSING services (['Work', 'Skills & Training', 'Resume Development'],)
# MISSING services (['Work', 'Skills & Training', 'Skills Assessment'],)
# MISSING services (['Work', 'Skills & Training', 'Specialized Training'],)
# MISSING services (['Work', 'Supported Employment'],)
# MISSING services (['Work', 'Workplace Rights'],)
# MISSING services (['Legal'], 'Services for legal representation, mediation, advocacy, citizenship and immigration, adoption and foster care, guardianship, civil rights and more.')
# MISSING services (['Legal', 'Advocacy & Legal Aid'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Adoption & Foster Care'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Adoption & Foster Care', 'Adoption & Foster Care'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Citizenship & Immigration'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Discrimination & Civil Rights'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Guardianship'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Identification Recovery'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Understand Government Programs'],)
# MISSING services (['Legal', 'Advocacy & Legal Aid', 'Workplace Rights'],)
# MISSING services (['Legal', 'Mediation'],)
# MISSING services (['Legal', 'Notary'],)
# MISSING services (['Legal', 'Representation'],)
# MISSING services (['Legal', 'Translation & Interpretation'],)
# MISSING situations (['Age Group', 'Adults'],)
# MISSING situations (['Age Group', 'Teens'],)
# MISSING situations (['Age Group', 'Children'],)
# MISSING situations (['Age Group', 'Seniors'],)
# MISSING situations (['Criminal History'], None)
# MISSING situations (['Criminal History', 'Ex-Offenders'],)
# MISSING situations (['Disability', 'Hearing Impairment'],)
# MISSING situations (['Disability', 'Mental Illness'],)
# MISSING situations (['Gender'], None)
# MISSING situations (['Gender', 'Women'],)
# MISSING situations (['Gender', 'Men'],)
# MISSING situations (['Gender', 'Transgender'],)
# MISSING situations (['Health', 'Alzheimers'],)
# MISSING situations (['Health', 'Seizure Disorder'],)
# MISSING situations (['Health', 'Substance Dependency'],)
# MISSING situations (['Health', 'Mental Illness'],)
# MISSING situations (['Sexuality'], None)
# MISSING situations (['Sexuality', 'LGBTQ'],)
# MISSING situations (['Survivors', 'All Survivors'],)

# %% [markdown]
# ### Check additions from openreferral/openeligibility and ensure we're not missing anything

# %%
import io
import csv

openreferral_additions = """
1391,"Adoption Counseling",1271,"Adoption & Foster Care","Open Eligibility"
1392,"Anger Management",1420,"Mental Health Care","Open Eligibility"
1393,"Before School Care",1277,"Daytime Care","Open Eligibility"
1394,"Business Loans",1415,"Loans","Open Eligibility"
1395,"Case Management",1292,"Navigating the System","Open Eligibility"
1396,"Community Support Services",1108,"Care","Open Eligibility"
1397,"Computer or Internet Access",1396,"Community Support Services","Open Eligibility"
1398,"Drug Testing",1178,"Addiction & Recovery","Open Eligibility"
1399,"Early Childhood Intervention",1219,"Prevent & Treat","Open Eligibility"
1400,"Efficiency Upgrades",1141,"Maintenance & Repairs","Open Eligibility"
1401,"Efficient Appliances",1163,"Home Goods","Open Eligibility"
1402,"Exercise & Fitness",1206,"Medical Care","Open Eligibility"
1403,"Family Counseling",1420,"Mental Health Care","Open Eligibility"
1404,"Fertility",1431,"Sexual & Reproductive Health","Open Eligibility"
1405,"Government Food Benefits",1405,"Government Food Benefits","Open Eligibility"
1406,"Group Therapy",1220,"Counseling","Open Eligibility"
1407,"Head Start",1277,"Daytime Care","Open Eligibility"
1408,"Health & Safety",1141,"Maintenance & Repairs","Open Eligibility"
1409,"Help Find Healthcare",1206,"Medical Care","Open Eligibility"
1410,"Help Pay for Car",1105,"Transit","Open Eligibility"
1411,"Help Pay for Internet or Phone",1116,"Help Pay for Housing","Open Eligibility"
1412,"Home Fuels",1163,"Home Goods","Open Eligibility"
1413,"Hospital Treatment",1219,"Prevent & Treat","Open Eligibility"
1414,"Individual Counseling",1220,"Counseling","Open Eligibility"
1415,"Loans",1107,"Money","Open Eligibility"
1416,"Meals",1102,"Food","Open Eligibility"
1417,"Medication Management",1219,"Prevent & Treat","Open Eligibility"
1418,"Medications for Addiction",1178,"Addiction & Recovery","Open Eligibility"
1419,"Medications for Mental Health",1420,"Mental Health Care","Open Eligibility"
1420,"Mental Health Care",1106,"Health","Open Eligibility"
1421,"Occupational Therapy",1219,"Prevent & Treat","Open Eligibility"
1422,"Peer Recovery Coaching",1303,"Support Network","Open Eligibility"
1423,"Personal Loans",1415,"Loans","Open Eligibility"
1424,"Personal Safety",1104,"Goods","Open Eligibility"
1425,"Pest Control",1141,"Maintenance & Repairs","Open Eligibility"
1426,"Physical Safety",1108,"Care","Open Eligibility"
1427,"Postnatal Care",1441,"Women's Health","Open Eligibility"
1428,"Primary Care",1206,"Medical Care","Open Eligibility"
1429,"Prosthesis",1169,"Medical Supplies","Open Eligibility"
1430,"Safety Education",1426,"Physical Safety","Open Eligibility"
1431,"Sexual & Reproductive Health",1219,"Prevent & Treat","Open Eligibility"
1432,"Skilled Nursing",1206,"Medical Care","Open Eligibility"
1433,"Speech Therapy",1219,"Prevent & Treat","Open Eligibility"
1434,"STD/STI Treatment & Prevention",1431,"Sexual & Reproductive Health","Open Eligibility"
1435,"Substance Abuse Counseling",1220,"Counseling","Open Eligibility"
1436,"Supplies for School",1163,"Home Goods","Open Eligibility"
1437,"Support & Service Animals",1219,"Prevent & Treat","Open Eligibility"
1438,"Temporary Shelter",1426,"Physical Safety","Open Eligibility"
1439,"Vision Care",1106,"Health","Open Eligibility"
1440,"Weather Relief",1396,"Community Support Services","Open Eligibility"
1441,"Women's Health",1431,"Sexual & Reproductive Health","Open Eligibility"
""".strip()

r = csv.reader(io.StringIO(openreferral_additions))

# %%
for line in r:
    name=line[1]
    assert name in names, "NAME: " + name

# %% [markdown]
# ### Mark equivalent slugs

# %%
for name, sects in names.items():
    slugs = sorted(set(s['slug'] for s in sects))
    if len(slugs) > 1:
        for section in sects:
            section['related'] = [s for s in slugs if section['slug'] != s]

# %% [markdown]
# ### Save the result in YAML format

# %%
import yaml
yaml.dump(sections, open('taxonomy.yaml', 'w'), sort_keys=False, width=240)

# %%
sections
# Out:
# [{'name': 'Human Services',
#   'slug': 'human_services',
#   'items': [{'name': 'food',
#     'slug': 'human_services:food',
#     'description': 'Services for meals, food pantries, help paying for food, food delivery, food benefits, and nutrition support.',
#     'items': [{'name': 'Community Gardens',
#       'slug': 'human_services:food:community_gardens'},
#      {'name': 'Emergency Food',
#       'slug': 'human_services:food:emergency_food',
#       'related': ['human_services:care:physical_safety:emergency_food',
#        'human_services:emergency:emergency_food']},
#      {'name': 'Food Delivery', 'slug': 'human_services:food:food_delivery'},
#      {'name': 'Food Pantry', 'slug': 'human_services:food:food_pantry'},
#      {'name': 'Meals', 'slug': 'human_services:food:meals'},
#      {'name': 'Help Pay for Food',
#       'slug': 'human_services:food:help_pay_for_food',
#       'items': [{'name': 'Government Food Benefits',
#         'slug': 'human_services:food:help_pay_for_food:government_food_benefits',
#         'related': ['human_services:money:financial_assistance:government_food_benefits',
#          'human_services:money:financial_assistance:help_pay_for_food:government_food_benefits',
#          'human_services:money:government_benefits:government_food_benefits']}],
#       'related': ['human_services:emergency:emergency_payments:help_pay_for_food',
#        'human_services:money:financial_assistance:help_pay_for_food',
#        'human_services:money:financial_assistance:help_pay_for_food:help_pay_for_food']},
#      {'name': 'Nutrition Education',
#       'slug': 'human_services:food:nutrition_education',
#       'related': ['human_services:education:more_education:health_education:nutrition_education',
#        'human_services:education:more_education:nutrition_education',
#        'human_services:health:health_education:nutrition_education']}]},
#    {'name': 'housing',
#     'slug': 'human_services:housing',
#     'description': 'Services for emergency, short- term and long- term housing, housing advice, help finding housing, and paying for housing.',
#     'items': [{'name': 'Temporary Shelter',
#       'slug': 'human_services:housing:temporary_shelter',
#       'items': [{'name': 'Weather Relief',
#         'slug': 'human_services:housing:temporary_shelter:weather_relief',
#         'related': ['human_services:care:community_support_services:weather_relief',
#          'human_services:care:physical_safety:temporary_shelter:weather_relief',
#          'human_services:care:physical_safety:weather_relief']}],
#       'related': ['human_services:care:physical_safety:temporary_shelter']},
#      {'name': 'Help Find Housing',
#       'slug': 'human_services:housing:help_find_housing',
#       'related': ['human_services:care:navigating_the_system:help_find_housing']},
#      {'name': 'Help Pay for Housing',
#       'slug': 'human_services:housing:help_pay_for_housing',
#       'items': [{'name': 'Help Pay for Utilities',
#         'slug': 'human_services:housing:help_pay_for_housing:help_pay_for_utilities',
#         'related': ['human_services:emergency:emergency_payments:help_pay_for_utilities',
#          'human_services:money:financial_assistance:help_pay_for_housing:help_pay_for_utilities',
#          'human_services:money:financial_assistance:help_pay_for_utilities']},
#        {'name': 'Help Pay for Internet or Phone',
#         'slug': 'human_services:housing:help_pay_for_housing:help_pay_for_internet_or_phone',
#         'related': ['human_services:money:financial_assistance:help_pay_for_housing:help_pay_for_internet_or_phone',
#          'human_services:money:financial_assistance:help_pay_for_internet_or_phone']},
#        {'name': 'Home & Renters Insurance',
#         'slug': 'human_services:housing:help_pay_for_housing:home_renters_insurance',
#         'related': ['human_services:money:financial_assistance:help_pay_for_housing:home_renters_insurance',
#          'human_services:money:financial_assistance:home_renters_insurance',
#          'human_services:money:insurance:home_renters_insurance']},
#        {'name': 'Housing Vouchers',
#         'slug': 'human_services:housing:help_pay_for_housing:housing_vouchers'}],
#       'related': ['human_services:emergency:emergency_payments:help_pay_for_housing',
#        'human_services:money:financial_assistance:help_pay_for_housing',
#        'human_services:money:financial_assistance:help_pay_for_housing:help_pay_for_housing']},
#      {'name': 'Maintenance & Repairs',
#       'slug': 'human_services:housing:maintenance_repairs',
#       'items': [{'name': 'Efficiency Upgrades',
#         'slug': 'human_services:housing:maintenance_repairs:efficiency_upgrades'},
#        {'name': 'Health & Safety',
#         'slug': 'human_services:housing:maintenance_repairs:health_safety'},
#        {'name': 'Pest Control',
#         'slug': 'human_services:housing:maintenance_repairs:pest_control'}],
#       'related': ['human_services:housing:help_pay_for_housing:maintenance_repairs']},
#      {'name': 'Housing Advice',
#       'slug': 'human_services:housing:housing_advice',
#       'items': [{'name': 'Foreclosure Counseling',
#         'slug': 'human_services:housing:housing_advice:foreclosure_counseling',
#         'related': ['human_services:education:more_education:financial_education:foreclosure_counseling',
#          'human_services:education:more_education:foreclosure_counseling',
#          'human_services:money:financial_education:foreclosure_counseling']},
#        {'name': 'Homebuyer Education',
#         'slug': 'human_services:housing:housing_advice:homebuyer_education',
#         'related': ['human_services:education:more_education:financial_education:homebuyer_education',
#          'human_services:education:more_education:homebuyer_education',
#          'human_services:money:financial_education:homebuyer_education']}]},
#      {'name': 'Residential Housing',
#       'slug': 'human_services:housing:residential_housing',
#       'items': [{'name': 'Long-Term Housing',
#         'slug': 'human_services:housing:residential_housing:long_term_housing',
#         'items': [{'name': 'Assisted Living',
#           'slug': 'human_services:housing:residential_housing:long_term_housing:assisted_living',
#           'related': ['human_services:care:residential_care:assisted_living',
#            'human_services:housing:residential_housing:assisted_living']},
#          {'name': 'Independent Living',
#           'slug': 'human_services:housing:residential_housing:long_term_housing:independent_living',
#           'related': ['human_services:housing:residential_housing:independent_living']},
#          {'name': 'Nursing Home',
#           'slug': 'human_services:housing:residential_housing:long_term_housing:nursing_home',
#           'related': ['human_services:care:residential_care:nursing_home',
#            'human_services:health:medical_care:nursing_home',
#            'human_services:health:medical_care:prevent_treat:nursing_home',
#            'human_services:housing:residential_housing:nursing_home',
#            'human_services:housing:residential_housing:short_term_housing:nursing_home']},
#          {'name': 'Public Housing',
#           'slug': 'human_services:housing:residential_housing:long_term_housing:public_housing',
#           'related': ['human_services:housing:residential_housing:public_housing']}],
#         'related': ['human_services:housing:residential_housing:long_term_housing:long_term_housing']},
#        {'name': 'Safe Housing',
#         'slug': 'human_services:housing:residential_housing:safe_housing',
#         'related': ['human_services:care:physical_safety:immediate_safety:safe_housing',
#          'human_services:care:physical_safety:safe_housing',
#          'human_services:emergency:immediate_safety:safe_housing']},
#        {'name': 'Short-Term Housing',
#         'slug': 'human_services:housing:residential_housing:short_term_housing',
#         'items': [{'name': 'Nursing Home',
#           'slug': 'human_services:housing:residential_housing:short_term_housing:nursing_home',
#           'related': ['human_services:care:residential_care:nursing_home',
#            'human_services:health:medical_care:nursing_home',
#            'human_services:health:medical_care:prevent_treat:nursing_home',
#            'human_services:housing:residential_housing:long_term_housing:nursing_home',
#            'human_services:housing:residential_housing:nursing_home']},
#          {'name': 'Sober Living',
#           'slug': 'human_services:housing:residential_housing:short_term_housing:sober_living',
#           'related': ['human_services:health:addiction_recovery:sober_living',
#            'human_services:housing:residential_housing:sober_living']}],
#         'related': ['human_services:housing:residential_housing:short_term_housing:short_term_housing']},
#        {'name': 'Assisted Living',
#         'slug': 'human_services:housing:residential_housing:assisted_living',
#         'related': ['human_services:care:residential_care:assisted_living',
#          'human_services:housing:residential_housing:long_term_housing:assisted_living']},
#        {'name': 'Independent Living',
#         'slug': 'human_services:housing:residential_housing:independent_living',
#         'related': ['human_services:housing:residential_housing:long_term_housing:independent_living']},
#        {'name': 'Nursing Home',
#         'slug': 'human_services:housing:residential_housing:nursing_home',
#         'related': ['human_services:care:residential_care:nursing_home',
#          'human_services:health:medical_care:nursing_home',
#          'human_services:health:medical_care:prevent_treat:nursing_home',
#          'human_services:housing:residential_housing:long_term_housing:nursing_home',
#          'human_services:housing:residential_housing:short_term_housing:nursing_home']},
#        {'name': 'Public Housing',
#         'slug': 'human_services:housing:residential_housing:public_housing',
#         'related': ['human_services:housing:residential_housing:long_term_housing:public_housing']},
#        {'name': 'Nursing Home',
#         'slug': 'human_services:housing:residential_housing:nursing_home',
#         'related': ['human_services:care:residential_care:nursing_home',
#          'human_services:health:medical_care:nursing_home',
#          'human_services:health:medical_care:prevent_treat:nursing_home',
#          'human_services:housing:residential_housing:long_term_housing:nursing_home',
#          'human_services:housing:residential_housing:short_term_housing:nursing_home']},
#        {'name': 'Sober Living',
#         'slug': 'human_services:housing:residential_housing:sober_living',
#         'related': ['human_services:health:addiction_recovery:sober_living',
#          'human_services:housing:residential_housing:short_term_housing:sober_living']}]}]},
#    {'name': 'goods',
#     'slug': 'human_services:goods',
#     'description': 'Services for clothing, furniture, baby supplies, toys and gifts, and other physical goods.',
#     'items': [{'name': 'Baby Supplies',
#       'slug': 'human_services:goods:baby_supplies',
#       'items': [{'name': 'Baby Clothes',
#         'slug': 'human_services:goods:baby_supplies:baby_clothes',
#         'related': ['human_services:goods:clothing:baby_clothes']},
#        {'name': 'Diapers & Formula',
#         'slug': 'human_services:goods:baby_supplies:diapers_formula'}]},
#      {'name': 'Clothing',
#       'slug': 'human_services:goods:clothing',
#       'items': [{'name': 'Baby Clothes',
#         'slug': 'human_services:goods:clothing:baby_clothes',
#         'related': ['human_services:goods:baby_supplies:baby_clothes']},
#        {'name': 'Clothes for School',
#         'slug': 'human_services:goods:clothing:clothes_for_school',
#         'related': ['human_services:education:help_pay_for_school:clothes_for_school',
#          'human_services:money:financial_assistance:clothes_for_school',
#          'human_services:money:financial_assistance:help_pay_for_school:clothes_for_school']},
#        {'name': 'Clothes for Work',
#         'slug': 'human_services:goods:clothing:clothes_for_work',
#         'related': ['human_services:work:help_pay_for_work_expenses:clothes_for_work']},
#        {'name': 'Clothing Vouchers',
#         'slug': 'human_services:goods:clothing:clothing_vouchers'}]},
#      {'name': 'Home Goods',
#       'slug': 'human_services:goods:home_goods',
#       'items': [{'name': 'Blankets & Fans',
#         'slug': 'human_services:goods:home_goods:blankets_fans'},
#        {'name': 'Books',
#         'slug': 'human_services:goods:home_goods:books',
#         'related': ['human_services:education:help_pay_for_school:books',
#          'human_services:money:financial_assistance:books',
#          'human_services:money:financial_assistance:help_pay_for_school:books']},
#        {'name': 'Furniture',
#         'slug': 'human_services:goods:home_goods:furniture'},
#        {'name': 'Home Fuels',
#         'slug': 'human_services:goods:home_goods:home_fuels'},
#        {'name': 'Efficient Appliances',
#         'slug': 'human_services:goods:home_goods:efficient_appliances'},
#        {'name': 'Personal Care Items',
#         'slug': 'human_services:goods:home_goods:personal_care_items'},
#        {'name': 'Supplies for School',
#         'slug': 'human_services:goods:home_goods:supplies_for_school',
#         'related': ['human_services:education:help_pay_for_school:supplies_for_school',
#          'human_services:money:financial_assistance:help_pay_for_school:supplies_for_school',
#          'human_services:money:financial_assistance:supplies_for_school']},
#        {'name': 'Supplies for Work',
#         'slug': 'human_services:goods:home_goods:supplies_for_work',
#         'related': ['human_services:work:help_pay_for_work_expenses:supplies_for_work']}]},
#      {'name': 'Medical Supplies',
#       'slug': 'human_services:goods:medical_supplies',
#       'items': [{'name': 'Assistive Technology',
#         'slug': 'human_services:goods:medical_supplies:assistive_technology',
#         'related': ['human_services:health:medical_care:assistive_technology',
#          'human_services:health:medical_care:medical_supplies:assistive_technology']},
#        {'name': 'Prosthesis',
#         'slug': 'human_services:goods:medical_supplies:prosthesis',
#         'related': ['human_services:health:medical_care:medical_supplies:prosthesis',
#          'human_services:health:medical_care:prosthesis']}],
#       'related': ['human_services:health:help_pay_for_healthcare:medical_supplies',
#        'human_services:health:medical_care:medical_supplies',
#        'human_services:money:financial_assistance:help_pay_for_healthcare:medical_supplies',
#        'human_services:money:financial_assistance:medical_supplies']},
#      {'name': 'Personal Safety',
#       'slug': 'human_services:goods:personal_safety'},
#      {'name': 'Toys & Gifts', 'slug': 'human_services:goods:toys_gifts'}]},
#    {'name': 'transit',
#     'slug': 'human_services:transit',
#     'description': 'Services for bus passes, transportation to school, healthcare, appointments, and more.',
#     'items': [{'name': 'Help Pay for Transit',
#       'slug': 'human_services:transit:help_pay_for_transit',
#       'items': [{'name': 'Bus Passes',
#         'slug': 'human_services:transit:help_pay_for_transit:bus_passes',
#         'related': ['human_services:money:financial_assistance:bus_passes',
#          'human_services:money:financial_assistance:help_pay_for_transit:bus_passes']},
#        {'name': 'Help Pay for Car',
#         'slug': 'human_services:transit:help_pay_for_transit:help_pay_for_car'},
#        {'name': 'Help Pay for Gas',
#         'slug': 'human_services:transit:help_pay_for_transit:help_pay_for_gas',
#         'related': ['human_services:emergency:emergency_payments:help_pay_for_gas',
#          'human_services:money:financial_assistance:help_pay_for_gas',
#          'human_services:money:financial_assistance:help_pay_for_transit:help_pay_for_gas']}],
#       'related': ['human_services:money:financial_assistance:help_pay_for_transit',
#        'human_services:money:financial_assistance:help_pay_for_transit:help_pay_for_transit']},
#      {'name': 'Transportation',
#       'slug': 'human_services:transit:transportation',
#       'items': [{'name': 'Transportation for Healthcare',
#         'slug': 'human_services:transit:transportation:transportation_for_healthcare',
#         'related': ['human_services:health:help_pay_for_healthcare:transportation_for_healthcare',
#          'human_services:money:financial_assistance:help_pay_for_healthcare:transportation_for_healthcare',
#          'human_services:money:financial_assistance:transportation_for_healthcare']},
#        {'name': 'Transportation for School',
#         'slug': 'human_services:transit:transportation:transportation_for_school',
#         'related': ['human_services:education:help_pay_for_school:transportation_for_school',
#          'human_services:money:financial_assistance:help_pay_for_school:transportation_for_school',
#          'human_services:money:financial_assistance:transportation_for_school']}]}]},
#    {'name': 'health',
#     'slug': 'human_services:health',
#     'description': 'Services for medical care, dental care, health education, addiction and recovery, help finding services, and help paying for healthcare.',
#     'items': [{'name': 'Addiction & Recovery',
#       'slug': 'human_services:health:addiction_recovery',
#       'items': [{'name': '12-Step',
#         'slug': 'human_services:health:addiction_recovery:12_step',
#         'related': ['human_services:care:support_network:12_step',
#          'human_services:care:support_network:support_groups:12_step']},
#        {'name': 'Detox',
#         'slug': 'human_services:health:addiction_recovery:detox'},
#        {'name': 'Drug Testing',
#         'slug': 'human_services:health:addiction_recovery:drug_testing'},
#        {'name': 'Medications for Addiction',
#         'slug': 'human_services:health:addiction_recovery:medications_for_addiction'},
#        {'name': 'Outpatient Treatment',
#         'slug': 'human_services:health:addiction_recovery:outpatient_treatment',
#         'related': ['human_services:health:medical_care:outpatient_treatment',
#          'human_services:health:medical_care:prevent_treat:outpatient_treatment',
#          'human_services:health:mental_health_care:outpatient_treatment']},
#        {'name': 'Peer Recovery Coaching',
#         'slug': 'human_services:health:addiction_recovery:peer_recovery_coaching',
#         'related': ['human_services:care:support_network:peer_recovery_coaching']},
#        {'name': 'Residential Treatment',
#         'slug': 'human_services:health:addiction_recovery:residential_treatment',
#         'related': ['human_services:care:residential_care:residential_treatment',
#          'human_services:health:medical_care:prevent_treat:residential_treatment',
#          'human_services:health:medical_care:residential_treatment',
#          'human_services:health:mental_health_care:residential_treatment']},
#        {'name': 'Sober Living',
#         'slug': 'human_services:health:addiction_recovery:sober_living',
#         'related': ['human_services:housing:residential_housing:short_term_housing:sober_living',
#          'human_services:housing:residential_housing:sober_living']},
#        {'name': 'Substance Abuse Counseling',
#         'slug': 'human_services:health:addiction_recovery:substance_abuse_counseling',
#         'related': ['human_services:health:mental_health_care:counseling:substance_abuse_counseling',
#          'human_services:health:mental_health_care:substance_abuse_counseling']}]},
#      {'name': 'Dental Care', 'slug': 'human_services:health:dental_care'},
#      {'name': 'End-of-Life Care',
#       'slug': 'human_services:health:end_of_life_care',
#       'items': [{'name': 'Bereavement',
#         'slug': 'human_services:health:end_of_life_care:bereavement',
#         'related': ['human_services:care:end_of_life_care:bereavement',
#          'human_services:care:support_network:bereavement',
#          'human_services:care:support_network:support_groups:bereavement',
#          'human_services:health:mental_health_care:bereavement']},
#        {'name': 'Burial & Funeral Help',
#         'slug': 'human_services:health:end_of_life_care:burial_funeral_help',
#         'related': ['human_services:care:end_of_life_care:burial_funeral_help']},
#        {'name': 'Hospice',
#         'slug': 'human_services:health:end_of_life_care:hospice',
#         'related': ['human_services:care:end_of_life_care:hospice']}],
#       'related': ['human_services:care:end_of_life_care']},
#      {'name': 'Health Education',
#       'slug': 'human_services:health:health_education',
#       'items': [{'name': 'Daily Life Skills',
#         'slug': 'human_services:health:health_education:daily_life_skills',
#         'related': ['human_services:education:skills_training:daily_life_skills']},
#        {'name': 'Disease Management',
#         'slug': 'human_services:health:health_education:disease_management',
#         'related': ['human_services:education:more_education:disease_management',
#          'human_services:education:more_education:health_education:disease_management',
#          'human_services:health:medical_care:disease_management',
#          'human_services:health:medical_care:prevent_treat:disease_management']},
#        {'name': 'Family Planning',
#         'slug': 'human_services:health:health_education:family_planning',
#         'related': ['human_services:education:more_education:family_planning',
#          'human_services:education:more_education:health_education:family_planning',
#          'human_services:health:sexual_reproductive_health:family_planning']},
#        {'name': 'Nutrition Education',
#         'slug': 'human_services:health:health_education:nutrition_education',
#         'related': ['human_services:education:more_education:health_education:nutrition_education',
#          'human_services:education:more_education:nutrition_education',
#          'human_services:food:nutrition_education']},
#        {'name': 'Parenting Education',
#         'slug': 'human_services:health:health_education:parenting_education',
#         'related': ['human_services:care:support_network:parenting_education',
#          'human_services:care:support_network:support_groups:parenting_education',
#          'human_services:education:more_education:health_education:parenting_education',
#          'human_services:education:more_education:parenting_education']},
#        {'name': 'Safety Education',
#         'slug': 'human_services:health:health_education:safety_education',
#         'related': ['human_services:care:physical_safety:safety_education',
#          'human_services:education:more_education:health_education:safety_education',
#          'human_services:education:more_education:safety_education']},
#        {'name': 'Sex Education',
#         'slug': 'human_services:health:health_education:sex_education',
#         'related': ['human_services:education:more_education:health_education:sex_education',
#          'human_services:education:more_education:sex_education',
#          'human_services:health:sexual_reproductive_health:sex_education']},
#        {'name': 'Understand Disability',
#         'slug': 'human_services:health:health_education:understand_disability',
#         'related': ['human_services:education:more_education:health_education:understand_disability',
#          'human_services:education:more_education:understand_disability']},
#        {'name': 'Understand Mental Health',
#         'slug': 'human_services:health:health_education:understand_mental_health',
#         'related': ['human_services:education:more_education:health_education:understand_mental_health',
#          'human_services:education:more_education:understand_mental_health',
#          'human_services:health:mental_health_care:understand_mental_health']}],
#       'related': ['human_services:education:more_education:health_education',
#        'human_services:education:more_education:health_education:health_education']},
#      {'name': 'Help Pay for Healthcare',
#       'slug': 'human_services:health:help_pay_for_healthcare',
#       'items': [{'name': 'Disability Benefits',
#         'slug': 'human_services:health:help_pay_for_healthcare:disability_benefits',
#         'related': ['human_services:money:financial_assistance:disability_benefits',
#          'human_services:money:financial_assistance:help_pay_for_healthcare:disability_benefits',
#          'human_services:money:government_benefits:disability_benefits']},
#        {'name': 'Discounted Healthcare',
#         'slug': 'human_services:health:help_pay_for_healthcare:discounted_healthcare',
#         'related': ['human_services:money:financial_assistance:discounted_healthcare',
#          'human_services:money:financial_assistance:help_pay_for_healthcare:discounted_healthcare']},
#        {'name': 'Health Insurance',
#         'slug': 'human_services:health:help_pay_for_healthcare:health_insurance',
#         'related': ['human_services:money:financial_assistance:health_insurance',
#          'human_services:money:financial_assistance:help_pay_for_healthcare:health_insurance',
#          'human_services:money:insurance:health_insurance']},
#        {'name': 'Prescription Assistance',
#         'slug': 'human_services:health:help_pay_for_healthcare:prescription_assistance',
#         'related': ['human_services:money:financial_assistance:help_pay_for_healthcare:prescription_assistance',
#          'human_services:money:financial_assistance:prescription_assistance']},
#        {'name': 'Transportation for Healthcare',
#         'slug': 'human_services:health:help_pay_for_healthcare:transportation_for_healthcare',
#         'related': ['human_services:money:financial_assistance:help_pay_for_healthcare:transportation_for_healthcare',
#          'human_services:money:financial_assistance:transportation_for_healthcare',
#          'human_services:transit:transportation:transportation_for_healthcare']}],
#       'related': ['human_services:emergency:emergency_payments:help_pay_for_healthcare',
#        'human_services:money:financial_assistance:help_pay_for_healthcare',
#        'human_services:money:financial_assistance:help_pay_for_healthcare:help_pay_for_healthcare']},
#      {'name': 'Medical Care',
#       'slug': 'human_services:health:medical_care',
#       'items': [{'name': 'Alternative Medicine',
#         'slug': 'human_services:health:medical_care:alternative_medicine'},
#        {'name': 'Checkup & Test',
#         'slug': 'human_services:health:medical_care:checkup_test',
#         'items': [{'name': 'Disability Screening',
#           'slug': 'human_services:health:medical_care:checkup_test:disability_screening',
#           'related': ['human_services:health:medical_care:disability_screening']},
#          {'name': 'Disease Screening',
#           'slug': 'human_services:health:medical_care:checkup_test:disease_screening',
#           'related': ['human_services:health:medical_care:disease_screening']},
#          {'name': 'Hearing Tests',
#           'slug': 'human_services:health:medical_care:checkup_test:hearing_tests',
#           'related': ['human_services:health:medical_care:hearing_tests']},
#          {'name': 'Pregnancy Tests',
#           'slug': 'human_services:health:medical_care:checkup_test:pregnancy_tests',
#           'related': ['human_services:health:medical_care:pregnancy_tests']}],
#         'related': ['human_services:health:medical_care:checkup_test:checkup_test']},
#        {'name': 'Exercise & Fitness',
#         'slug': 'human_services:health:medical_care:exercise_fitness',
#         'related': ['human_services:care:community_support_services:exercise_fitness']},
#        {'name': 'Help Find Healthcare',
#         'slug': 'human_services:health:medical_care:help_find_healthcare'},
#        {'name': 'Medical Supplies',
#         'slug': 'human_services:health:medical_care:medical_supplies',
#         'items': [{'name': 'Assistive Technology',
#           'slug': 'human_services:health:medical_care:medical_supplies:assistive_technology',
#           'related': ['human_services:goods:medical_supplies:assistive_technology',
#            'human_services:health:medical_care:assistive_technology']},
#          {'name': 'Prosthesis',
#           'slug': 'human_services:health:medical_care:medical_supplies:prosthesis',
#           'related': ['human_services:goods:medical_supplies:prosthesis',
#            'human_services:health:medical_care:prosthesis']}],
#         'related': ['human_services:goods:medical_supplies',
#          'human_services:health:help_pay_for_healthcare:medical_supplies',
#          'human_services:money:financial_assistance:help_pay_for_healthcare:medical_supplies',
#          'human_services:money:financial_assistance:medical_supplies']},
#        {'name': 'Prevent & Treat',
#         'slug': 'human_services:health:medical_care:prevent_treat',
#         'items': [{'name': 'Counseling',
#           'slug': 'human_services:health:medical_care:prevent_treat:counseling',
#           'related': ['human_services:care:support_network:counseling',
#            'human_services:health:medical_care:counseling',
#            'human_services:health:mental_health_care:counseling']},
#          {'name': 'Disease Management',
#           'slug': 'human_services:health:medical_care:prevent_treat:disease_management',
#           'related': ['human_services:education:more_education:disease_management',
#            'human_services:education:more_education:health_education:disease_management',
#            'human_services:health:health_education:disease_management',
#            'human_services:health:medical_care:disease_management']},
#          {'name': 'Early Childhood Intervention',
#           'slug': 'human_services:health:medical_care:prevent_treat:early_childhood_intervention',
#           'related': ['human_services:care:daytime_care:early_childhood_intervention',
#            'human_services:health:medical_care:early_childhood_intervention']},
#          {'name': 'HIV Treatment',
#           'slug': 'human_services:health:medical_care:prevent_treat:hiv_treatment',
#           'related': ['human_services:health:medical_care:hiv_treatment',
#            'human_services:health:sexual_reproductive_health:hiv_treatment',
#            'human_services:health:sexual_reproductive_health:std_sti_treatment_prevention:hiv_treatment']},
#          {'name': 'Hospital Treatment',
#           'slug': 'human_services:health:medical_care:prevent_treat:hospital_treatment',
#           'related': ['human_services:health:medical_care:hospital_treatment',
#            'human_services:health:mental_health_care:hospital_treatment']},
#          {'name': 'In-Home Support',
#           'slug': 'human_services:health:medical_care:prevent_treat:in_home_support',
#           'related': ['human_services:care:support_network:in_home_support',
#            'human_services:health:medical_care:in_home_support']},
#          {'name': 'Medication Management',
#           'slug': 'human_services:health:medical_care:prevent_treat:medication_management',
#           'related': ['human_services:health:medical_care:medication_management']},
#          {'name': 'Nursing Home',
#           'slug': 'human_services:health:medical_care:prevent_treat:nursing_home',
#           'related': ['human_services:care:residential_care:nursing_home',
#            'human_services:health:medical_care:nursing_home',
#            'human_services:housing:residential_housing:long_term_housing:nursing_home',
#            'human_services:housing:residential_housing:nursing_home',
#            'human_services:housing:residential_housing:short_term_housing:nursing_home']},
#          {'name': 'Occupational Therapy',
#           'slug': 'human_services:health:medical_care:prevent_treat:occupational_therapy',
#           'related': ['human_services:health:medical_care:occupational_therapy']},
#          {'name': 'Outpatient Treatment',
#           'slug': 'human_services:health:medical_care:prevent_treat:outpatient_treatment',
#           'related': ['human_services:health:addiction_recovery:outpatient_treatment',
#            'human_services:health:medical_care:outpatient_treatment',
#            'human_services:health:mental_health_care:outpatient_treatment']},
#          {'name': 'Pain Management',
#           'slug': 'human_services:health:medical_care:prevent_treat:pain_management',
#           'related': ['human_services:care:end_of_life_care:pain_management',
#            'human_services:health:end_of_life_care:pain_management',
#            'human_services:health:medical_care:pain_management']},
#          {'name': 'Physical Therapy',
#           'slug': 'human_services:health:medical_care:prevent_treat:physical_therapy',
#           'related': ['human_services:health:medical_care:physical_therapy']},
#          {'name': 'Residential Treatment',
#           'slug': 'human_services:health:medical_care:prevent_treat:residential_treatment',
#           'related': ['human_services:care:residential_care:residential_treatment',
#            'human_services:health:addiction_recovery:residential_treatment',
#            'human_services:health:medical_care:residential_treatment',
#            'human_services:health:mental_health_care:residential_treatment']},
#          {'name': 'Specialized Therapy',
#           'slug': 'human_services:health:medical_care:prevent_treat:specialized_therapy',
#           'related': ['human_services:health:medical_care:specialized_therapy']},
#          {'name': 'Speech Therapy',
#           'slug': 'human_services:health:medical_care:prevent_treat:speech_therapy',
#           'related': ['human_services:health:medical_care:speech_therapy']},
#          {'name': 'Vaccinations',
#           'slug': 'human_services:health:medical_care:prevent_treat:vaccinations',
#           'related': ['human_services:health:medical_care:vaccinations']}],
#         'related': ['human_services:health:medical_care:prevent_treat:prevent_treat']},
#        {'name': 'Personal Hygiene',
#         'slug': 'human_services:health:medical_care:personal_hygiene'},
#        {'name': 'Primary Care',
#         'slug': 'human_services:health:medical_care:primary_care'},
#        {'name': 'Skilled Nursing',
#         'slug': 'human_services:health:medical_care:skilled_nursing'},
#        {'name': 'Support & Service Animals',
#         'slug': 'human_services:health:medical_care:support_service_animals',
#         'related': ['human_services:health:mental_health_care:support_service_animals']},
#        {'name': 'Disability Screening',
#         'slug': 'human_services:health:medical_care:disability_screening',
#         'related': ['human_services:health:medical_care:checkup_test:disability_screening']},
#        {'name': 'Disease Screening',
#         'slug': 'human_services:health:medical_care:disease_screening',
#         'related': ['human_services:health:medical_care:checkup_test:disease_screening']},
#        {'name': 'Hearing Tests',
#         'slug': 'human_services:health:medical_care:hearing_tests',
#         'related': ['human_services:health:medical_care:checkup_test:hearing_tests']},
#        {'name': 'Pregnancy Tests',
#         'slug': 'human_services:health:medical_care:pregnancy_tests',
#         'related': ['human_services:health:medical_care:checkup_test:pregnancy_tests']},
#        {'name': 'Assistive Technology',
#         'slug': 'human_services:health:medical_care:assistive_technology',
#         'related': ['human_services:goods:medical_supplies:assistive_technology',
#          'human_services:health:medical_care:medical_supplies:assistive_technology']},
#        {'name': 'Prosthesis',
#         'slug': 'human_services:health:medical_care:prosthesis',
#         'related': ['human_services:goods:medical_supplies:prosthesis',
#          'human_services:health:medical_care:medical_supplies:prosthesis']},
#        {'name': 'Counseling',
#         'slug': 'human_services:health:medical_care:counseling',
#         'related': ['human_services:care:support_network:counseling',
#          'human_services:health:medical_care:prevent_treat:counseling',
#          'human_services:health:mental_health_care:counseling']},
#        {'name': 'Disease Management',
#         'slug': 'human_services:health:medical_care:disease_management',
#         'related': ['human_services:education:more_education:disease_management',
#          'human_services:education:more_education:health_education:disease_management',
#          'human_services:health:health_education:disease_management',
#          'human_services:health:medical_care:prevent_treat:disease_management']},
#        {'name': 'Early Childhood Intervention',
#         'slug': 'human_services:health:medical_care:early_childhood_intervention',
#         'related': ['human_services:care:daytime_care:early_childhood_intervention',
#          'human_services:health:medical_care:prevent_treat:early_childhood_intervention']},
#        {'name': 'HIV Treatment',
#         'slug': 'human_services:health:medical_care:hiv_treatment',
#         'related': ['human_services:health:medical_care:prevent_treat:hiv_treatment',
#          'human_services:health:sexual_reproductive_health:hiv_treatment',
#          'human_services:health:sexual_reproductive_health:std_sti_treatment_prevention:hiv_treatment']},
#        {'name': 'Hospital Treatment',
#         'slug': 'human_services:health:medical_care:hospital_treatment',
#         'related': ['human_services:health:medical_care:prevent_treat:hospital_treatment',
#          'human_services:health:mental_health_care:hospital_treatment']},
#        {'name': 'In-Home Support',
#         'slug': 'human_services:health:medical_care:in_home_support',
#         'related': ['human_services:care:support_network:in_home_support',
#          'human_services:health:medical_care:prevent_treat:in_home_support']},
#        {'name': 'Medication Management',
#         'slug': 'human_services:health:medical_care:medication_management',
#         'related': ['human_services:health:medical_care:prevent_treat:medication_management']},
#        {'name': 'Nursing Home',
#         'slug': 'human_services:health:medical_care:nursing_home',
#         'related': ['human_services:care:residential_care:nursing_home',
#          'human_services:health:medical_care:prevent_treat:nursing_home',
#          'human_services:housing:residential_housing:long_term_housing:nursing_home',
#          'human_services:housing:residential_housing:nursing_home',
#          'human_services:housing:residential_housing:short_term_housing:nursing_home']},
#        {'name': 'Occupational Therapy',
#         'slug': 'human_services:health:medical_care:occupational_therapy',
#         'related': ['human_services:health:medical_care:prevent_treat:occupational_therapy']},
#        {'name': 'Outpatient Treatment',
#         'slug': 'human_services:health:medical_care:outpatient_treatment',
#         'related': ['human_services:health:addiction_recovery:outpatient_treatment',
#          'human_services:health:medical_care:prevent_treat:outpatient_treatment',
#          'human_services:health:mental_health_care:outpatient_treatment']},
#        {'name': 'Pain Management',
#         'slug': 'human_services:health:medical_care:pain_management',
#         'related': ['human_services:care:end_of_life_care:pain_management',
#          'human_services:health:end_of_life_care:pain_management',
#          'human_services:health:medical_care:prevent_treat:pain_management']},
#        {'name': 'Physical Therapy',
#         'slug': 'human_services:health:medical_care:physical_therapy',
#         'related': ['human_services:health:medical_care:prevent_treat:physical_therapy']},
#        {'name': 'Residential Treatment',
#         'slug': 'human_services:health:medical_care:residential_treatment',
#         'related': ['human_services:care:residential_care:residential_treatment',
#          'human_services:health:addiction_recovery:residential_treatment',
#          'human_services:health:medical_care:prevent_treat:residential_treatment',
#          'human_services:health:mental_health_care:residential_treatment']},
#        {'name': 'Specialized Therapy',
#         'slug': 'human_services:health:medical_care:specialized_therapy',
#         'related': ['human_services:health:medical_care:prevent_treat:specialized_therapy']},
#        {'name': 'Speech Therapy',
#         'slug': 'human_services:health:medical_care:speech_therapy',
#         'related': ['human_services:health:medical_care:prevent_treat:speech_therapy']},
#        {'name': 'Vaccinations',
#         'slug': 'human_services:health:medical_care:vaccinations',
#         'related': ['human_services:health:medical_care:prevent_treat:vaccinations']}]},
#      {'name': 'Mental Health Care',
#       'slug': 'human_services:health:mental_health_care',
#       'items': [{'name': 'Anger Management',
#         'slug': 'human_services:health:mental_health_care:anger_management'},
#        {'name': 'Bereavement',
#         'slug': 'human_services:health:mental_health_care:bereavement',
#         'related': ['human_services:care:end_of_life_care:bereavement',
#          'human_services:care:support_network:bereavement',
#          'human_services:care:support_network:support_groups:bereavement',
#          'human_services:health:end_of_life_care:bereavement']},
#        {'name': 'Counseling',
#         'slug': 'human_services:health:mental_health_care:counseling',
#         'items': [{'name': 'Group Therapy',
#           'slug': 'human_services:health:mental_health_care:counseling:group_therapy',
#           'related': ['human_services:health:mental_health_care:group_therapy']},
#          {'name': 'Substance Abuse Counseling',
#           'slug': 'human_services:health:mental_health_care:counseling:substance_abuse_counseling',
#           'related': ['human_services:health:addiction_recovery:substance_abuse_counseling',
#            'human_services:health:mental_health_care:substance_abuse_counseling']},
#          {'name': 'Family Counseling',
#           'slug': 'human_services:health:mental_health_care:counseling:family_counseling',
#           'related': ['human_services:health:mental_health_care:family_counseling']},
#          {'name': 'Individual Counseling',
#           'slug': 'human_services:health:mental_health_care:counseling:individual_counseling',
#           'related': ['human_services:health:mental_health_care:individual_counseling']}],
#         'related': ['human_services:care:support_network:counseling',
#          'human_services:health:medical_care:counseling',
#          'human_services:health:medical_care:prevent_treat:counseling']},
#        {'name': 'Hospital Treatment',
#         'slug': 'human_services:health:mental_health_care:hospital_treatment',
#         'related': ['human_services:health:medical_care:hospital_treatment',
#          'human_services:health:medical_care:prevent_treat:hospital_treatment']},
#        {'name': 'Medications for Mental Health',
#         'slug': 'human_services:health:mental_health_care:medications_for_mental_health'},
#        {'name': 'Mental Health Evaluation',
#         'slug': 'human_services:health:mental_health_care:mental_health_evaluation'},
#        {'name': 'Outpatient Treatment',
#         'slug': 'human_services:health:mental_health_care:outpatient_treatment',
#         'related': ['human_services:health:addiction_recovery:outpatient_treatment',
#          'human_services:health:medical_care:outpatient_treatment',
#          'human_services:health:medical_care:prevent_treat:outpatient_treatment']},
#        {'name': 'Psychiatric Emergency Services',
#         'slug': 'human_services:health:mental_health_care:psychiatric_emergency_services',
#         'related': ['human_services:emergency:psychiatric_emergency_services',
#          'human_services:health:medical_care:psychiatric_emergency_services']},
#        {'name': 'Residential Treatment',
#         'slug': 'human_services:health:mental_health_care:residential_treatment',
#         'related': ['human_services:care:residential_care:residential_treatment',
#          'human_services:health:addiction_recovery:residential_treatment',
#          'human_services:health:medical_care:prevent_treat:residential_treatment',
#          'human_services:health:medical_care:residential_treatment']},
#        {'name': 'Support & Service Animals',
#         'slug': 'human_services:health:mental_health_care:support_service_animals',
#         'related': ['human_services:health:medical_care:support_service_animals']},
#        {'name': 'Understand Mental Health',
#         'slug': 'human_services:health:mental_health_care:understand_mental_health',
#         'related': ['human_services:education:more_education:health_education:understand_mental_health',
#          'human_services:education:more_education:understand_mental_health',
#          'human_services:health:health_education:understand_mental_health']},
#        {'name': 'Group Therapy',
#         'slug': 'human_services:health:mental_health_care:group_therapy',
#         'related': ['human_services:health:mental_health_care:counseling:group_therapy']},
#        {'name': 'Substance Abuse Counseling',
#         'slug': 'human_services:health:mental_health_care:substance_abuse_counseling',
#         'related': ['human_services:health:addiction_recovery:substance_abuse_counseling',
#          'human_services:health:mental_health_care:counseling:substance_abuse_counseling']},
#        {'name': 'Family Counseling',
#         'slug': 'human_services:health:mental_health_care:family_counseling',
#         'related': ['human_services:health:mental_health_care:counseling:family_counseling']},
#        {'name': 'Individual Counseling',
#         'slug': 'human_services:health:mental_health_care:individual_counseling',
#         'related': ['human_services:health:mental_health_care:counseling:individual_counseling']}]},
#      {'name': 'Sexual & Reproductive Health',
#       'slug': 'human_services:health:sexual_reproductive_health',
#       'items': [{'name': 'Family Planning',
#         'slug': 'human_services:health:sexual_reproductive_health:family_planning',
#         'items': [{'name': 'Birth Control',
#           'slug': 'human_services:health:sexual_reproductive_health:family_planning:birth_control',
#           'related': ['human_services:health:medical_care:birth_control',
#            'human_services:health:sexual_reproductive_health:birth_control']}],
#         'related': ['human_services:education:more_education:family_planning',
#          'human_services:education:more_education:health_education:family_planning',
#          'human_services:health:health_education:family_planning']},
#        {'name': 'Fertility',
#         'slug': 'human_services:health:sexual_reproductive_health:fertility'},
#        {'name': 'Sex Education',
#         'slug': 'human_services:health:sexual_reproductive_health:sex_education',
#         'related': ['human_services:education:more_education:health_education:sex_education',
#          'human_services:education:more_education:sex_education',
#          'human_services:health:health_education:sex_education']},
#        {'name': 'STD/STI Treatment & Prevention',
#         'slug': 'human_services:health:sexual_reproductive_health:std_sti_treatment_prevention',
#         'items': [{'name': 'HIV Treatment',
#           'slug': 'human_services:health:sexual_reproductive_health:std_sti_treatment_prevention:hiv_treatment',
#           'related': ['human_services:health:medical_care:hiv_treatment',
#            'human_services:health:medical_care:prevent_treat:hiv_treatment',
#            'human_services:health:sexual_reproductive_health:hiv_treatment']}]},
#        {'name': "Women's Health",
#         'slug': 'human_services:health:sexual_reproductive_health:women_s_health',
#         'items': [{'name': 'Maternity Care',
#           'slug': 'human_services:health:sexual_reproductive_health:women_s_health:maternity_care',
#           'related': ['human_services:health:medical_care:maternity_care',
#            'human_services:health:sexual_reproductive_health:maternity_care']},
#          {'name': 'Postnatal Care',
#           'slug': 'human_services:health:sexual_reproductive_health:women_s_health:postnatal_care',
#           'related': ['human_services:health:sexual_reproductive_health:postnatal_care']}]},
#        {'name': 'Birth Control',
#         'slug': 'human_services:health:sexual_reproductive_health:birth_control',
#         'related': ['human_services:health:medical_care:birth_control',
#          'human_services:health:sexual_reproductive_health:family_planning:birth_control']},
#        {'name': 'HIV Treatment',
#         'slug': 'human_services:health:sexual_reproductive_health:hiv_treatment',
# ...
#       'related': ['human_situations:health:cancer:vaginal_cancer']},
#      {'name': 'Vulvar Cancer',
#       'slug': 'human_situations:health:vulvar_cancer',
#       'related': ['human_situations:health:cancer:vulvar_cancer']},
#      {'name': 'Wilms Tumor',
#       'slug': 'human_situations:health:wilms_tumor',
#       'related': ['human_situations:health:cancer:wilms_tumor']},
#      {'name': 'Central Nervous System Germ Cell Tumor',
#       'slug': 'human_situations:health:central_nervous_system_germ_cell_tumor',
#       'related': ['human_situations:health:cancer:central_nervous_system_germ_cell_tumor',
#        'human_situations:health:cancer:germ_cell_tumor:central_nervous_system_germ_cell_tumor',
#        'human_situations:health:germ_cell_tumor:central_nervous_system_germ_cell_tumor']},
#      {'name': 'Ovarian Germ Cell Tumor',
#       'slug': 'human_situations:health:ovarian_germ_cell_tumor',
#       'related': ['human_situations:health:cancer:germ_cell_tumor:ovarian_germ_cell_tumor',
#        'human_situations:health:cancer:ovarian_germ_cell_tumor',
#        'human_situations:health:germ_cell_tumor:ovarian_germ_cell_tumor']},
#      {'name': 'Testicular Germ Cell Tumor',
#       'slug': 'human_situations:health:testicular_germ_cell_tumor',
#       'related': ['human_situations:health:cancer:germ_cell_tumor:testicular_germ_cell_tumor',
#        'human_situations:health:cancer:testicular_germ_cell_tumor',
#        'human_situations:health:germ_cell_tumor:testicular_germ_cell_tumor']},
#      {'name': 'Acute Lymphoblastic Leukemia (ALL)',
#       'slug': 'human_situations:health:acute_lymphoblastic_leukemia_all',
#       'related': ['human_situations:health:cancer:acute_lymphoblastic_leukemia_all',
#        'human_situations:health:cancer:leukemia:acute_lymphoblastic_leukemia_all',
#        'human_situations:health:leukemia:acute_lymphoblastic_leukemia_all']},
#      {'name': 'Acute Myeloid Leukemia (AML)',
#       'slug': 'human_situations:health:acute_myeloid_leukemia_aml',
#       'related': ['human_situations:health:cancer:acute_myeloid_leukemia_aml',
#        'human_situations:health:cancer:leukemia:acute_myeloid_leukemia_aml',
#        'human_situations:health:leukemia:acute_myeloid_leukemia_aml']},
#      {'name': 'Chronic Lymphocytic Leukemia (CLL)',
#       'slug': 'human_situations:health:chronic_lymphocytic_leukemia_cll',
#       'related': ['human_situations:health:cancer:chronic_lymphocytic_leukemia_cll',
#        'human_situations:health:cancer:leukemia:chronic_lymphocytic_leukemia_cll',
#        'human_situations:health:leukemia:chronic_lymphocytic_leukemia_cll']},
#      {'name': 'Chronic Myelogenous Leukemia (CML)',
#       'slug': 'human_situations:health:chronic_myelogenous_leukemia_cml',
#       'related': ['human_situations:health:cancer:chronic_myelogenous_leukemia_cml',
#        'human_situations:health:cancer:leukemia:chronic_myelogenous_leukemia_cml',
#        'human_situations:health:leukemia:chronic_myelogenous_leukemia_cml']},
#      {'name': 'Hairy Cell Leukemia',
#       'slug': 'human_situations:health:hairy_cell_leukemia',
#       'related': ['human_situations:health:cancer:hairy_cell_leukemia',
#        'human_situations:health:cancer:leukemia:hairy_cell_leukemia',
#        'human_situations:health:leukemia:hairy_cell_leukemia']},
#      {'name': 'Childhood Lung Cancer',
#       'slug': 'human_situations:health:childhood_lung_cancer',
#       'related': ['human_situations:health:cancer:childhood_lung_cancer',
#        'human_situations:health:cancer:lung_cancer:childhood_lung_cancer',
#        'human_situations:health:lung_cancer:childhood_lung_cancer']},
#      {'name': 'Non-Small Cell Lung Cancer',
#       'slug': 'human_situations:health:non_small_cell_lung_cancer',
#       'related': ['human_situations:health:cancer:lung_cancer:non_small_cell_lung_cancer',
#        'human_situations:health:cancer:non_small_cell_lung_cancer',
#        'human_situations:health:lung_cancer:non_small_cell_lung_cancer']},
#      {'name': 'Small Cell Lung Cancer',
#       'slug': 'human_situations:health:small_cell_lung_cancer',
#       'related': ['human_situations:health:cancer:lung_cancer:small_cell_lung_cancer',
#        'human_situations:health:cancer:small_cell_lung_cancer',
#        'human_situations:health:lung_cancer:small_cell_lung_cancer']},
#      {'name': 'AIDS-Related Lymphoma',
#       'slug': 'human_situations:health:aids_related_lymphoma',
#       'related': ['human_situations:health:cancer:aids_related_lymphoma',
#        'human_situations:health:cancer:lymphoma:aids_related_lymphoma',
#        'human_situations:health:lymphoma:aids_related_lymphoma']},
#      {'name': 'Burkitt Lymphoma',
#       'slug': 'human_situations:health:burkitt_lymphoma',
#       'related': ['human_situations:health:cancer:burkitt_lymphoma',
#        'human_situations:health:cancer:lymphoma:burkitt_lymphoma',
#        'human_situations:health:lymphoma:burkitt_lymphoma']},
#      {'name': 'Cutaneous T-Cell Lymphoma',
#       'slug': 'human_situations:health:cutaneous_t_cell_lymphoma',
#       'related': ['human_situations:health:cancer:cutaneous_t_cell_lymphoma',
#        'human_situations:health:cancer:lymphoma:cutaneous_t_cell_lymphoma',
#        'human_situations:health:lymphoma:cutaneous_t_cell_lymphoma']},
#      {'name': 'Hodgkin Lymphoma',
#       'slug': 'human_situations:health:hodgkin_lymphoma',
#       'related': ['human_situations:health:cancer:hodgkin_lymphoma',
#        'human_situations:health:cancer:lymphoma:hodgkin_lymphoma',
#        'human_situations:health:lymphoma:hodgkin_lymphoma']},
#      {'name': 'Non-Hodgkin Lymphoma',
#       'slug': 'human_situations:health:non_hodgkin_lymphoma',
#       'related': ['human_situations:health:cancer:lymphoma:non_hodgkin_lymphoma',
#        'human_situations:health:cancer:non_hodgkin_lymphoma',
#        'human_situations:health:lymphoma:non_hodgkin_lymphoma']},
#      {'name': 'Primary Central Nervous System Lymphoma(CNS)',
#       'slug': 'human_situations:health:primary_central_nervous_system_lymphoma_cns',
#       'related': ['human_situations:health:cancer:lymphoma:primary_central_nervous_system_lymphoma_cns',
#        'human_situations:health:cancer:primary_central_nervous_system_lymphoma_cns',
#        'human_situations:health:lymphoma:primary_central_nervous_system_lymphoma_cns']},
#      {'name': 'Ewing Sarcoma',
#       'slug': 'human_situations:health:ewing_sarcoma',
#       'related': ['human_situations:health:cancer:ewing_sarcoma',
#        'human_situations:health:cancer:sarcoma:ewing_sarcoma',
#        'human_situations:health:sarcoma:ewing_sarcoma']},
#      {'name': 'Kaposi Sarcoma',
#       'slug': 'human_situations:health:kaposi_sarcoma',
#       'related': ['human_situations:health:cancer:kaposi_sarcoma',
#        'human_situations:health:cancer:sarcoma:kaposi_sarcoma',
#        'human_situations:health:sarcoma:kaposi_sarcoma']},
#      {'name': 'Osteosarcoma Sarcoma',
#       'slug': 'human_situations:health:osteosarcoma_sarcoma',
#       'related': ['human_situations:health:cancer:osteosarcoma_sarcoma',
#        'human_situations:health:cancer:sarcoma:osteosarcoma_sarcoma',
#        'human_situations:health:sarcoma:osteosarcoma_sarcoma']},
#      {'name': 'Rhabdomyosarcoma Sarcoma',
#       'slug': 'human_situations:health:rhabdomyosarcoma_sarcoma',
#       'related': ['human_situations:health:cancer:rhabdomyosarcoma_sarcoma',
#        'human_situations:health:cancer:sarcoma:rhabdomyosarcoma_sarcoma',
#        'human_situations:health:sarcoma:rhabdomyosarcoma_sarcoma']},
#      {'name': 'Soft Tissue Sarcoma',
#       'slug': 'human_situations:health:soft_tissue_sarcoma',
#       'related': ['human_situations:health:cancer:sarcoma:soft_tissue_sarcoma',
#        'human_situations:health:cancer:soft_tissue_sarcoma',
#        'human_situations:health:sarcoma:soft_tissue_sarcoma']},
#      {'name': 'Uterine Sarcoma',
#       'slug': 'human_situations:health:uterine_sarcoma',
#       'related': ['human_situations:health:cancer:sarcoma:uterine_sarcoma',
#        'human_situations:health:cancer:uterine_sarcoma',
#        'human_situations:health:sarcoma:uterine_sarcoma']},
#      {'name': 'Melanoma',
#       'slug': 'human_situations:health:melanoma',
#       'related': ['human_situations:health:cancer:melanoma',
#        'human_situations:health:cancer:skin_cancer:melanoma',
#        'human_situations:health:skin_cancer:melanoma']},
#      {'name': 'HIV/AIDS',
#       'slug': 'human_situations:health:hiv_aids',
#       'related': ['human_situations:health:infectious_disease:hiv_aids']},
#      {'name': 'Alzheimers', 'slug': 'human_situations:health:alzheimers'},
#      {'name': 'Seizure Disorder',
#       'slug': 'human_situations:health:seizure_disorder'},
#      {'name': 'Substance Dependency',
#       'slug': 'human_situations:health:substance_dependency',
#       'related': ['human_situations:substance_dependency']},
#      {'name': 'Mental Illness',
#       'slug': 'human_situations:health:mental_illness',
#       'related': ['human_situations:disability:mental_illness']}],
#     'related': ['human_services:health']},
#    {'name': 'Household',
#     'slug': 'human_situations:household',
#     'items': [{'name': 'Individuals',
#       'slug': 'human_situations:household:individuals'},
#      {'name': 'Families',
#       'slug': 'human_situations:household:families',
#       'items': [{'name': 'With Children',
#         'slug': 'human_situations:household:families:with_children',
#         'related': ['human_situations:household:with_children']},
#        {'name': 'Single Parent',
#         'slug': 'human_situations:household:families:single_parent',
#         'related': ['human_situations:household:single_parent']}]},
#      {'name': 'With Children',
#       'slug': 'human_situations:household:with_children',
#       'related': ['human_situations:household:families:with_children']},
#      {'name': 'Single Parent',
#       'slug': 'human_situations:household:single_parent',
#       'related': ['human_situations:household:families:single_parent']}]},
#    {'name': 'Housing',
#     'slug': 'human_situations:housing',
#     'items': [{'name': 'Home Owners',
#       'slug': 'human_situations:housing:home_owners'},
#      {'name': 'Home Renters', 'slug': 'human_situations:housing:home_renters'},
#      {'name': 'Homeless', 'slug': 'human_situations:housing:homeless'},
#      {'name': 'Near Homeless',
#       'slug': 'human_situations:housing:near_homeless'},
#      {'name': 'Runaways', 'slug': 'human_situations:housing:runaways'}],
#     'related': ['human_services:housing']},
#    {'name': 'Income',
#     'slug': 'human_situations:income',
#     'items': [{'name': 'Benefit Recipients',
#       'slug': 'human_situations:income:benefit_recipients'},
#      {'name': 'Low-Income', 'slug': 'human_situations:income:low_income'}]},
#    {'name': 'Insurance',
#     'slug': 'human_situations:insurance',
#     'items': [{'name': 'Uninsured',
#       'slug': 'human_situations:insurance:uninsured'},
#      {'name': 'Underinsured',
#       'slug': 'human_situations:insurance:underinsured'}],
#     'related': ['human_services:money:insurance']},
#    {'name': 'Language',
#     'slug': 'human_situations:language',
#     'items': [{'name': 'Limited English',
#       'slug': 'human_situations:language:limited_english'}]},
#    {'name': 'Mental Health',
#     'slug': 'human_situations:mental_health',
#     'items': [{'name': 'Anxiety',
#       'slug': 'human_situations:mental_health:anxiety'},
#      {'name': 'Bipolar', 'slug': 'human_situations:mental_health:bipolar'},
#      {'name': 'Brain Injury',
#       'slug': 'human_situations:mental_health:brain_injury'},
#      {'name': 'Depression',
#       'slug': 'human_situations:mental_health:depression'},
#      {'name': 'Eating Disorder',
#       'slug': 'human_situations:mental_health:eating_disorder'},
#      {'name': 'Suicidal Thoughts',
#       'slug': 'human_situations:mental_health:suicidal_thoughts'}]},
#    {'name': 'Race/Ethnicity',
#     'slug': 'human_situations:race_ethnicity',
#     'items': [{'name': 'African American',
#       'slug': 'human_situations:race_ethnicity:african_american'},
#      {'name': 'Asian', 'slug': 'human_situations:race_ethnicity:asian'},
#      {'name': 'Latino', 'slug': 'human_situations:race_ethnicity:latino'},
#      {'name': 'Native American',
#       'slug': 'human_situations:race_ethnicity:native_american'}]},
#    {'name': 'Role',
#     'slug': 'human_situations:role',
#     'items': [{'name': 'Caregivers',
#       'slug': 'human_situations:role:caregivers'},
#      {'name': 'Spouses', 'slug': 'human_situations:role:spouses'},
#      {'name': 'Dependents', 'slug': 'human_situations:role:dependents'},
#      {'name': 'Fathers', 'slug': 'human_situations:role:fathers'},
#      {'name': 'Mothers', 'slug': 'human_situations:role:mothers'},
#      {'name': 'Parents', 'slug': 'human_situations:role:parents'}]},
#    {'name': 'Substance Dependency',
#     'slug': 'human_situations:substance_dependency',
#     'items': [{'name': 'Alcohol Dependency',
#       'slug': 'human_situations:substance_dependency:alcohol_dependency'},
#      {'name': 'Dual Diagnosis',
#       'slug': 'human_situations:substance_dependency:dual_diagnosis'},
#      {'name': 'Opioid Dependency',
#       'slug': 'human_situations:substance_dependency:opioid_dependency'},
#      {'name': 'Smoker',
#       'slug': 'human_situations:substance_dependency:smoker'}],
#     'related': ['human_situations:health:substance_dependency']},
#    {'name': 'Sexual Orientation & Identity',
#     'slug': 'human_situations:sexual_orientation_identity',
#     'items': [{'name': 'LGBTQ+',
#       'slug': 'human_situations:sexual_orientation_identity:lgbtq'},
#      {'name': 'Transgender',
#       'slug': 'human_situations:sexual_orientation_identity:transgender',
#       'related': ['human_situations:gender:transgender']}]},
#    {'name': 'Survivors',
#     'slug': 'human_situations:survivors',
#     'items': [{'name': 'Trauma Survivors',
#       'slug': 'human_situations:survivors:trauma_survivors'},
#      {'name': 'Abuse or Neglect Survivors',
#       'slug': 'human_situations:survivors:abuse_or_neglect_survivors'},
#      {'name': 'Burn Survivors',
#       'slug': 'human_situations:survivors:burn_survivors'},
#      {'name': 'All Cancer Survivors',
#       'slug': 'human_situations:survivors:all_cancer_survivors'},
#      {'name': 'Childhood Cancer Survivors',
#       'slug': 'human_situations:survivors:childhood_cancer_survivors'},
#      {'name': 'Young Adult Cancer Survivors',
#       'slug': 'human_situations:survivors:young_adult_cancer_survivors'},
#      {'name': 'Adult Cancer Survivors',
#       'slug': 'human_situations:survivors:adult_cancer_survivors'},
#      {'name': 'Domestic Violence Survivors',
#       'slug': 'human_situations:survivors:domestic_violence_survivors'},
#      {'name': 'Human Trafficking Survivors',
#       'slug': 'human_situations:survivors:human_trafficking_survivors'},
#      {'name': 'Natural Disaster Survivors',
#       'slug': 'human_situations:survivors:natural_disaster_survivors'},
#      {'name': 'Sexual Assault Survivors',
#       'slug': 'human_situations:survivors:sexual_assault_survivors'},
#      {'name': 'All Survivors',
#       'slug': 'human_situations:survivors:all_survivors'}]},
#    {'name': 'Urgency',
#     'slug': 'human_situations:urgency',
#     'items': [{'name': 'In Crisis',
#       'slug': 'human_situations:urgency:in_crisis'},
#      {'name': 'In Danger', 'slug': 'human_situations:urgency:in_danger'},
#      {'name': 'Emergency',
#       'slug': 'human_situations:urgency:emergency',
#       'related': ['human_services:emergency']}]},
#    {'name': 'Criminal History',
#     'slug': 'human_situations:criminal_history',
#     'items': [{'name': 'Ex-Offenders',
#       'slug': 'human_situations:criminal_history:ex_offenders'}]},
#    {'name': 'Gender',
#     'slug': 'human_situations:gender',
#     'items': [{'name': 'Women', 'slug': 'human_situations:gender:women'},
#      {'name': 'Men', 'slug': 'human_situations:gender:men'},
#      {'name': 'Transgender',
#       'slug': 'human_situations:gender:transgender',
#       'related': ['human_situations:sexual_orientation_identity:transgender']}]},
#    {'name': 'Sexuality',
#     'slug': 'human_situations:sexuality',
#     'items': [{'name': 'LGBTQ',
#       'slug': 'human_situations:sexuality:lgbtq'}]}]}]
